# %% [markdown]
# ## Cleaning IRL Data

# %%
#import  os,warnings and pandas libraries
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from warnings import simplefilter
# ignore warnings to clean up output cells
simplefilter("ignore")

# %%
#listing files from the working directory into list
files_list =os.listdir('.')
files_list
# Out:
# ['.git',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  'ARIMA RESULTS.txt',
#  'Average price 1970 -2001.csv',
#  'Average price 2001-2011.csv',
#  'Average price 2011-2022.csv',
#  'CA 2 Zdenko Zahorec.ipynb',
#  'Dashboard.py',
#  'Download links.txt',
#  'Organic Food Sentiment Analysis.ipynb',
#  'sarima_irl.pkl',
#  'sarima_usa.pkl',
#  'US Steak prices.csv']

# %%
#seting columns dispay option to 'max'- to see all columns in dataset
pd.set_option('display.max.columns', None)
#importing dataframe irl_1 containing data from 1997-2001
df_irl1= pd.read_csv(r'Average price 1970 -2001.csv')
df_irl1
# Out:
#      STATISTIC              Statistic2  TLIST(M1)    Month  C02438V02948  \
# 0        CPM08  National Average Price     199701  1997M01         10010
# 1        CPM08  National Average Price     199701  1997M01         10020
# 2        CPM08  National Average Price     199701  1997M01         10030
# 3        CPM08  National Average Price     199701  1997M01         10040
# 4        CPM08  National Average Price     199701  1997M01         10050
# ...        ...                     ...        ...      ...           ...
# 3948     CPM08  National Average Price     200111  2001M11         11820
# 3949     CPM08  National Average Price     200111  2001M11         30430
# 3950     CPM08  National Average Price     200111  2001M11         30440
# 3951     CPM08  National Average Price     200111  2001M11         30450
# 3952     CPM08  National Average Price     200111  2001M11         30460
#
#                                       Consumer Item UNIT  VALUE
# 0                               Round steak per kg.  IEP  6.119
# 1                             Sirloin steak per kg.  IEP  8.053
# 2                                 Rib steak per kg.  IEP  4.023
# 3                       Leg beef (boneless) per kg.  IEP  4.269
# 4                         Brisket pot roast per kg.  IEP  4.097
# ...                                             ...  ...    ...
# 3948  Filtered cigarettes, standard size per 20 pk.  IEP  3.847
# 3949                         Leaded petrol per ltr.  IEP    NaN
# 3950                     Petrol - unleaded per ltr.  IEP  0.619
# 3951                  Liquid petroleum gas per ltr.  IEP  0.512
# 3952                                Diesel per ltr.  IEP  0.578
#
# [3953 rows x 8 columns]

# %%
# checking minimum and maximum values to see start and end date
df_irl1['TLIST(M1)'].describe()
# Out:
# count      3953.000000
# mean     199903.016949
# std         140.100566
# min      199701.000000
# 25%      199803.000000
# 50%      199906.000000
# 75%      200009.000000
# max      200111.000000
# Name: TLIST(M1), dtype: float64

# %%
#importing dataframe irl_2 containing data from 2001-2011
df_irl2= pd.read_csv(r'Average price 2001-2011.csv')
df_irl2
# Out:
#       STATISTIC                Statistic  TLIST(M1)    Month  C02363V02844  \
# 0         CPM04  National Average  Price     200112  2001M12         10010
# 1         CPM04  National Average  Price     200112  2001M12         10020
# 2         CPM04  National Average  Price     200112  2001M12         10030
# 3         CPM04  National Average  Price     200112  2001M12         10040
# 4         CPM04  National Average  Price     200112  2001M12         10050
# ...         ...                      ...        ...      ...           ...
# 10522     CPM04  National Average  Price     201112  2011M12         80001
# 10523     CPM04  National Average  Price     201112  2011M12         80002
# 10524     CPM04  National Average  Price     201112  2011M12         80003
# 10525     CPM04  National Average  Price     201112  2011M12         80004
# 10526     CPM04  National Average  Price     201112  2011M12         80005
#
#                                      Consumer Item  UNIT   VALUE
# 0                              Round steak per kg.  Euro   8.414
# 1                            Sirloin steak per kg.  Euro  12.095
# 2                          Striploin steak per kg.  Euro  16.448
# 3                   Roast beef topside/rib per kg.  Euro   8.726
# 4                 Sliced/diced beef pieces per kg.  Euro   7.041
# ...                                            ...   ...     ...
# 10522               1 litre, low fat milk per ltr.  Euro   1.044
# 10523                Large (size 2) eggs per dozen  Euro     NaN
# 10524               Medium (size 3) eggs per dozen  Euro     NaN
# 10525                White, plain flour per 2 kgs.  Euro     NaN
# 10526  Fine quality wine - take home (75cl bottle)  Euro     NaN
#
# [10527 rows x 8 columns]

# %%
# checking minimum and maximum values to see start and end date
df_irl2['TLIST(M1)'].describe()
# Out:
# count     10527.000000
# mean     200652.000000
# std         290.289519
# min      200112.000000
# 25%      200406.000000
# 50%      200612.000000
# 75%      200906.000000
# max      201112.000000
# Name: TLIST(M1), dtype: float64

# %%
#importing dataframe irl_3 containing data from 2011-2022
df_irl3= pd.read_csv(r'Average price 2011-2022.csv')
df_irl3
# Out:
#      STATISTIC               Statistic  TLIST(M1)    Month  C02363V03422  \
# 0        CPM12  National Average Price     201112  2011M12         10020
# 1        CPM12  National Average Price     201112  2011M12         10030
# 2        CPM12  National Average Price     201112  2011M12         10040
# 3        CPM12  National Average Price     201112  2011M12         10050
# 4        CPM12  National Average Price     201112  2011M12         10190
# ...        ...                     ...        ...      ...           ...
# 9343     CPM12  National Average Price     202202  2022M02         30400
# 9344     CPM12  National Average Price     202202  2022M02         30410
# 9345     CPM12  National Average Price     202202  2022M02         30690
# 9346     CPM12  National Average Price     202202  2022M02         30700
# 9347     CPM12  National Average Price     202202  2022M02         30720
#
#                               Consumer Item  UNIT   VALUE
# 0        White, self raising flour per 2 kg  Euro     NaN
# 1           Brown, wholemeal flour per 2 kg  Euro     NaN
# 2     Bread, white sliced pan, large (800g)  Euro     NaN
# 3     Bread, brown sliced pan, large (800g)  Euro     NaN
# 4                        Spaghetti per 500g  Euro     NaN
# ...                                     ...   ...     ...
# 9343                             Cinema fee  Euro  10.313
# 9344                         Nightclubs fee  Euro     NaN
# 9345                     Gent's dry cut fee  Euro  17.157
# 9346     Gent's wash, cut, and blow dry fee  Euro     NaN
# 9347     Ladies' wash, cut and blow dry fee  Euro  46.857
#
# [9348 rows x 8 columns]

# %%
# checking minimum and maximum values to see start and end date
df_irl3['TLIST(M1)'].describe()
# Out:
# count      9348.000000
# mean     201660.934959
# std         296.191212
# min      201112.000000
# 25%      201406.000000
# 50%      201701.000000
# 75%      201908.000000
# max      202202.000000
# Name: TLIST(M1), dtype: float64

# %%
#drop repeating columns from December 2011 that appear in df_irl2 & df_irl3 dataframes
df_irl3 = df_irl3[df_irl3['TLIST(M1)'] != 201112]

# %%
#check are duplicated values removed
df_irl3['TLIST(M1)'].describe()
# Out:
# count      9272.000000
# mean     201665.434426
# std         293.185906
# min      201201.000000
# 25%      201407.000000
# 50%      201701.500000
# 75%      201908.000000
# max      202202.000000
# Name: TLIST(M1), dtype: float64

# %%
#create function to check how many rows contain 'steak' substring in all three IRL dataframes
dfs = [df_irl1,df_irl2,df_irl3]
def steaks(lists):
    column_1=lists.drop_duplicates(subset = ['Consumer Item']) #drop duplicated values
    column_1=column_1[column_1['Consumer Item'].str.contains('steak')] # keep only observations that contain string 'steak'
    column_1 = column_1['Consumer Item'] #keep only 'Consumer Item' column
    print(column_1)
for lists in dfs:
    steaks(lists)
# Out:
# 0       Round steak per kg.
# 1     Sirloin steak per kg.
# 2         Rib steak per kg.
# 13       Pork steak per kg.
# Name: Consumer Item, dtype: object
# 0         Round steak per kg.
# 1       Sirloin steak per kg.
# 2     Striploin steak per kg.
# 12         Pork steak per kg.
# 21       Salmon steak per kg.
# Name: Consumer Item, dtype: object
# 81      Sirloin steak per kg
# 82    Striploin steak per kg
# 86         Pork steak per kg
# Name: Consumer Item, dtype: object

# %%
#rename column in df_irl3 to match column names in dfs 1&2
df_irl3['Consumer Item'] = df_irl3['Consumer Item'].replace(['Sirloin steak per kg'],'Sirloin steak per kg.')

# %%
#create blank list
lst=[]
#use for loop  to itterate through all 3 IRL datasets
for lists in dfs:
    lists=lists.rename(columns = {'Consumer Item':'SteakType','TLIST(M1)':'Daystamp'}) #rename columns for easier manipulation
    lists=lists.loc[(lists.SteakType.str.contains('Sirloin'))] #keep only observations that contain string 'Sirloin'  
    lists = lists.pivot_table('VALUE', ['Daystamp'], 'SteakType') # use pivot table function to create variables from observations
    lists= lists.rename_axis('ID',axis=1) # add variable name to ID column
    lists= lists.reset_index() # reset index- daystamp don't appear if don't reset index
    lst.append(lists) #apend observations into list
df_irl = pd.concat(lst, axis=0, ignore_index=True)#create dataframe from the created list
df_irl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Daystamp               302 non-null    int64
#  1   Sirloin steak per kg.  302 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 4.8 KB

# %%
#check for blank values
df_irl.head()
# Out:
# ID  Daystamp  Sirloin steak per kg.
# 0     199701                  8.053
# 1     199702                  8.276
# 2     199703                  8.124
# 3     199704                  8.503
# 4     199705                  8.397

# %%
#create date values from current integer values in column 'Daystamp'
df_irl['Daystamp'] = pd.to_datetime(df_irl['Daystamp'].apply(str) + '01', format='%Y%m%d', errors='ignore')
df_irl['Year']= df_irl['Daystamp'].dt.year #Creating 'Year' column that will be used in visualisations
df_irl['Month']= df_irl['Daystamp'].dt.month #Creating 'Month' column that will be used in visualisations
df_irl.set_index('Daystamp',inplace =True)
df_irl
# Out:
# ID          Sirloin steak per kg.  Year  Month
# Daystamp
# 1997-01-01                  8.053  1997      1
# 1997-02-01                  8.276  1997      2
# 1997-03-01                  8.124  1997      3
# 1997-04-01                  8.503  1997      4
# 1997-05-01                  8.397  1997      5
# ...                           ...   ...    ...
# 2021-10-01                 14.209  2021     10
# 2021-11-01                 14.209  2021     11
# 2021-12-01                 14.258  2021     12
# 2022-01-01                 14.258  2022      1
# 2022-02-01                 14.254  2022      2
#
# [302 rows x 3 columns]

# %%
#drop last two rows- to have end of year data
df_irl.drop(df_irl.tail(2).index,inplace=True) 
#describe dataframe
df_irl['Sirloin steak per kg.'].describe()
# Out:
# count    300.000000
# mean      13.360170
# std        2.605816
# min        7.994000
# 25%       12.175250
# 50%       14.161500
# 75%       15.471000
# max       16.982000
# Name: Sirloin steak per kg., dtype: float64

# %%
#check average price per every year
df_irl_year=df_irl.groupby('Year').mean()
df_irl_year
# Out:
# ID    Sirloin steak per kg.  Month
# Year
# 1997               8.315500    6.5
# 1998               8.336583    6.5
# 1999               8.464167    6.5
# 2000               9.175833    6.5
# 2001               9.938417    6.5
# 2002              12.545083    6.5
# 2003              12.700083    6.5
# 2004              12.883917    6.5
# 2005              11.846000    6.5
# 2006              12.971250    6.5
# 2007              14.280833    6.5
# 2008              15.260083    6.5
# 2009              14.441167    6.5
# 2010              13.620167    6.5
# 2011              14.173917    6.5
# 2012              15.495250    6.5
# 2013              16.347583    6.5
# 2014              16.191583    6.5
# 2015              15.903000    6.5
# 2016              15.745500    6.5
# 2017              15.652667    6.5
# 2018              15.018417    6.5
# 2019              15.164250    6.5
# 2020              15.191750    6.5
# 2021              14.341250    6.5

# %%
# importing seaborn module
import seaborn as sns
import matplotlib.pyplot as plt
#enhance line plot
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_irl.index,y='Sirloin steak per kg.',data=df_irl,color='#599664', linewidth=2)
Time_series.set_title('Sirloin steak price in Ireland from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg.',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
plt.figure(figsize=(24, 10))
axs=sns.boxplot(x=df_irl.Year, y=df_irl['Sirloin steak per kg.'])
axs.set_title('Sirloin steak price in Ireland',fontsize=30)
axs.set_ylabel('Price per kg',fontsize=20)
axs.set_xlabel('Year',fontsize=20)
plt.show()

# %%
#remove outliers using GroupBy median
grp = df_irl.groupby('Year')['Sirloin steak per kg.']
df_irl['Sirloin steak per kg.'] = (df_irl['Sirloin steak per kg.'].where(grp.transform('quantile', q=0.95) > df_irl['Sirloin steak per kg.'], 
                            grp.transform('median')))

# %%
plt.figure(figsize=(24, 10))
axs=sns.boxplot(x=df_irl.Year, y=df_irl['Sirloin steak per kg.'])
axs.set_title('Count Of Traffic 2008',fontsize=30)
axs.set_ylabel('Number of Vehicles',fontsize=20)
axs.set_xlabel('Year',fontsize=20)
plt.show()

# %%
#import numpy module
import numpy as np
def plot_poisson(df, col='Sirloin steak per kg.', n_pts=100):
    #get the mean value of our data
    lm = df[col].mean() 
    #define poisson disribution data
    poisdata = np.random.poisson(lm, n_pts)
    #plot histogram
    plt.hist(poisdata, density=True, alpha=0.5)
    plt.xlabel("X")
    plt.ylabel("P(X|\mu)")
    plt.title("Poisson PMF")
    plt.show()
plot_poisson(df_irl)

# %%
#import normal distribution module
from scipy.stats import norm  
#fitting data
fit = norm.pdf(df_irl['Sirloin steak per kg.'], np.mean(df_irl['Sirloin steak per kg.']), np.std(df_irl['Sirloin steak per kg.']))  
plt.plot(df_irl['Sirloin steak per kg.'],fit,'-')
#plot histogram of our data
plt.hist(df_irl['Sirloin steak per kg.'],density=True)      
plt.show()

# %%
#crete correlation matrix
corrmat = df_irl.corr()
sns.heatmap(corrmat,annot=True,square=True)
# Out:
# <AxesSubplot:xlabel='ID', ylabel='ID'>

# %%
#create pairplot
sns.pairplot(data=df_irl, hue='Month',height=2)

# %% [markdown]
# ## Cleaning USA Data

# %%
#importing dataframe USA containing data from 1989-2022
df_usa= pd.read_csv(r'US Steak prices.csv')
df_usa.head(20)
# Out:
#    CPI Average Price Data, U.S. city average (AP)  \
# 0                             Original Data Value
# 1                                             NaN
# 2                                      Series Id:
# 3                                   Series Title:
# 4                                           Area:
# 5                                           Item:
# 6                                          Years:
# 7                                             NaN
# 8                                       Series ID
# 9                                   APU0000703613
# 10                                  APU0000703613
# 11                                  APU0000703613
# 12                                  APU0000703613
# 13                                  APU0000703613
# 14                                  APU0000703613
# 15                                  APU0000703613
# 16                                  APU0000703613
# 17                                  APU0000703613
# 18                                  APU0000703613
# 19                                  APU0000703613
#
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                       APU0000703613        NaN        NaN
# 3   Steak, sirloin, USDA Choice, boneless, per lb....        NaN        NaN
# 4                                   U.S. city average        NaN        NaN
# 5   Steak, sirloin, USDA Choice, boneless, per lb....        NaN        NaN
# 6                                        1989 to 2022        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                                Year     Period      Value
# 9                                                1989        M01      3.854
# 10                                               1989        M02      3.948
# 11                                               1989        M03      3.934
# 12                                               1989        M04      3.888
# 13                                               1989        M05      4.015
# 14                                               1989        M06      4.043
# 15                                               1989        M07      4.146
# 16                                               1989        M08      3.991
# 17                                               1989        M09      3.950
# 18                                               1989        M10      3.761
# 19                                               1989        M11      3.806
#
#     Unnamed: 4  Unnamed: 5
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN

# %%
#import dataset again, but skip firdt 9 rows to get correct column names
df_usa= pd.read_csv(r'US Steak prices.csv',skiprows=9)
df_usa['Period']=df_usa['Period'].str[1:] # remove 'M' character from 'Period' column
df_usa['Year']=df_usa['Year'].astype(str) + df_usa["Period"] # merge columns 'Year' and 'Period' 
df_usa =df_usa.drop(['Series ID', 'Unnamed: 4','Unnamed: 5','Period'], axis=1) #drop unused columns
df_usa=df_usa.rename(columns = {'Year':'Daystamp'}) # remane 'Year' column to mach IRL dataset
df_usa= df_usa.rename_axis('ID',axis=1) # Add column name to the index column
df_usa.head()
# Out:
# ID Daystamp  Value
# 0    198901  3.854
# 1    198902  3.948
# 2    198903  3.934
# 3    198904  3.888
# 4    198905  4.015

# %%
#check for blank values
df_usa_blanks =  df_usa.loc[df_usa['Value'].isnull(), :]
df_usa_blanks
# Out:
# Empty DataFrame
# Columns: [Daystamp, Value]
# Index: []

# %%
#create date values from current integer values in column 'Daystamp'
df_usa['Daystamp'] = pd.to_datetime(df_usa['Daystamp'].apply(str) + '01', format='%Y%m%d', errors='ignore')
df_usa['Year']= df_usa['Daystamp'].dt.year #Creating 'Year' column that will be used in visualisations
df_usa['Month']= df_usa['Daystamp'].dt.month #Creating 'Month' column that will be used in visualisations
df_usa.set_index('Daystamp',inplace =True)
df_usa
# Out:
# ID           Value  Year  Month
# Daystamp
# 1989-01-01   3.854  1989      1
# 1989-02-01   3.948  1989      2
# 1989-03-01   3.934  1989      3
# 1989-04-01   3.888  1989      4
# 1989-05-01   4.015  1989      5
# ...            ...   ...    ...
# 2021-11-01  11.508  2021     11
# 2021-12-01  11.055  2021     12
# 2022-01-01  10.826  2022      1
# 2022-02-01  10.584  2022      2
# 2022-03-01  10.658  2022      3
#
# [399 rows x 3 columns]

# %%
df_usa=df_usa.rename(columns = {'Value':'Sirloin steak per kg.'}) #rename 'Value' column to match IRL dataset
df_usa['Sirloin steak per kg.']=2.2* df_usa['Sirloin steak per kg.'] #convert price from pounds into kilograms
df_usa
# Out:
# ID          Sirloin steak per kg.  Year  Month
# Daystamp
# 1989-01-01                 8.4788  1989      1
# 1989-02-01                 8.6856  1989      2
# 1989-03-01                 8.6548  1989      3
# 1989-04-01                 8.5536  1989      4
# 1989-05-01                 8.8330  1989      5
# ...                           ...   ...    ...
# 2021-11-01                25.3176  2021     11
# 2021-12-01                24.3210  2021     12
# 2022-01-01                23.8172  2022      1
# 2022-02-01                23.2848  2022      2
# 2022-03-01                23.4476  2022      3
#
# [399 rows x 3 columns]

# %%
# after comparing IRL/USA datasets - remove unmached data from USA dataset
df_usa = df_usa[(df_usa.index > '1996-12-1') & (df_usa.index<= '2021-12-1')]
print(df_usa.info())
df_irl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 300 entries, 1997-01-01 to 2021-12-01
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sirloin steak per kg.  300 non-null    float64
#  1   Year                   300 non-null    int64
#  2   Month                  300 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 9.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 300 entries, 1997-01-01 to 2021-12-01
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sirloin steak per kg.  300 non-null    float64
#  1   Year                   300 non-null    int64
#  2   Month                  300 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 17.5 KB

# %%
#enhance line plot
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_usa.index,y='Sirloin steak per kg.',data=df_usa,color='#599664', linewidth=3)
Time_series.set_title('Sirloin steak price in USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg/Euro',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
#check average price per every year
df_usa_year=df_usa.groupby('Year').mean()
df_usa_year
# Out:
# ID    Sirloin steak per kg.  Month
# Year
# 1997               9.255767    6.5
# 1998               9.216350    6.5
# 1999               9.611800    6.5
# 2000              10.401233    6.5
# 2001              11.598400    6.5
# 2002              11.655967    6.5
# 2003              13.076067    6.5
# 2004              14.568583    6.5
# 2005              13.434483    6.5
# 2006              13.149400    6.5
# 2007              13.137300    6.5
# 2008              13.181667    6.5
# 2009              12.834433    6.5
# 2010              12.818300    6.5
# 2011              13.695183    6.5
# 2012              14.632750    6.5
# 2013              15.024900    6.5
# 2014              16.921300    6.5
# 2015              18.854733    6.5
# 2016              18.448650    6.5
# 2017              17.704867    6.5
# 2018              18.484033    6.5
# 2019              18.420967    6.5
# 2020              19.692200    6.5
# 2021              22.685850    6.5

# %%
plt.figure(figsize=(24, 10))
axs=sns.boxplot(x=df_usa.Year, y=df_usa['Sirloin steak per kg.'])
axs.set_title('Sirloin steak price in USA',fontsize=30)
axs.set_ylabel('Price per Kg/Euro',fontsize=20)
axs.set_xlabel('Year',fontsize=20)
plt.show()

# %%
#remove outliers in USA data using GroupBy median
grp = df_usa.groupby('Year')['Sirloin steak per kg.']
df_usa['Sirloin steak per kg.'] = (df_usa['Sirloin steak per kg.'].where(grp.transform('quantile', q=0.95) > df_usa['Sirloin steak per kg.'], 
                            grp.transform('median')))

# %%
plt.figure(figsize=(24, 10))
axs=sns.boxplot(x=df_usa.Year, y=df_usa['Sirloin steak per kg.'])
axs.set_title('Sirloin steak price in USA',fontsize=30)
axs.set_ylabel('Price per Kg/Euro',fontsize=20)
axs.set_xlabel('Year',fontsize=20)
plt.show()

# %%
#plot poisson distribution for USA data
plot_poisson(df_usa)

# %%
#crete correlation matrix
corrmat = df_usa.corr()
sns.heatmap(corrmat,annot=True,square=True)
# Out:
# <AxesSubplot:xlabel='ID', ylabel='ID'>

# %%
#create pairplot
sns.pairplot(data=df_usa, hue='Month',height=2)

# %%
#backup IRL ad USA datasets for Machine Learning part as Inferential statistics park will change the dataframe structure
df_irlML =df_irl.copy()# create copy of the dataframe to use with ML Models
df_usaML =df_usa.copy()# create copy of the dataframe to use with ML Model

# %% [markdown]
# # Inferential statistics
# ##### 1. Linear regresion

# %%
#linear regression
from sklearn.linear_model import LinearRegression
df_irl['Time'] = np.arange(len(df_irl.index))
X = df_irl.loc[:, ['Time']]  #indepenedent variable
y = df_irl.loc[:, 'Sirloin steak per kg.']  #target variable
#fit the model
model = LinearRegression()
model.fit(X, y)
#Store the fitted values as a time series 
y_pred = pd.Series(model.predict(X), index=X.index)
ax = y.plot(color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    figsize=(15,5))
ax = y_pred.plot(ax=ax, linewidth=3)
ax.set_title('Time Plot of Sirloin Steak data IRL');

# %% [markdown]
# ##### 1a. Linear regresion with lag

# %%
#forcast with series lag
df_irl['Lag'] = df_irl['Sirloin steak per kg.'].shift(1)

X = df_irl.loc[:, ['Lag']]
X.dropna(inplace=True)  # drop missing values in the feature set
y = df_irl.loc[:, 'Sirloin steak per kg.']  # create the target
y, X = y.align(X, join='inner')  # drop corresponding values in target

model = LinearRegression()
model.fit(X, y)

#get model results
r_sq = model.score(X, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('coefficients:', model.coef_)
# Out:
# coefficient of determination: 0.952174348963907
# intercept: 0.429621294438542
# coefficients: [0.96926207]

# %%
#predict results
y_pred = pd.Series(model.predict(X), index=X.index)
ax = y.plot(color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    figsize=(15,5))
ax = y_pred.plot()

#fix colours

# %% [markdown]
# ##### 2. Mood’s Median Test (Appendix 1 of the report)

# %%
diff_irl= np.diff(df_irl['Sirloin steak per kg.'])

# %%
diff_irl= pd.DataFrame(diff_irl, columns=['difference'])
diff_irl.head()
# Out:
#    difference
# 0       0.223
# 1      -0.152
# 2       0.279
# 3      -0.006
# 4       0.045

# %%
diff_usa= np.diff(df_usa['Sirloin steak per kg.'])

# %%
diff_usa= pd.DataFrame(diff_usa, columns=['difference'])
diff_usa.head()
# Out:
#    difference
# 0     -0.3124
# 1      0.2156
# 2      0.1936
# 3      0.0198
# 4     -0.0484

# %%
#add country code to the each dataframe
diff_usa['Country']='USA'
diff_irl['Country']='IRL'
#merge 'difference' datasets 
df_diff = pd.concat([diff_usa, diff_irl], axis=0, join='inner')
#find overall median
overall_median = df_diff['difference'].median()
overall_median
# Out:
# 0.02829999999999977

# %%
#find out how many observations are above/below overall_median in each country
df_diff.groupby('Country')['difference'].apply(lambda x : pd.Series(x>overall_median).value_counts()).\
        unstack().rename(columns={True:'Above_med',False:'Below_med'})
# Out:
#          Below_med  Above_med
# Country
# IRL            151        148
# USA            148        151

# %% [markdown]
# <p style="color:green;"> *Continuation of this test will continue in the report appendix 1.

# %% [markdown]
# ##### 3.Kruskal-Wallis Test (Appendix 2 of the report)

# %%
#observe are the means equal on the steak prices for the last 3 observed years in the USA.
#get observations for 3 last years and sort them by price asccending
df_usa_KWT = df_usa[df_usa.index > "2018-12-31"].sort_values('Sirloin steak per kg.')
#add ranks to each observation
df_usa_KWT.insert(0, 'Rank', range(1, 1 + len(df_usa_KWT)))

# %%
df_usa_KWT.head()
# Out:
# ID          Rank  Sirloin steak per kg.  Year  Month
# Daystamp
# 2019-09-01     1                17.7826  2019      9
# 2019-06-01     2                17.8926  2019      6
# 2019-08-01     3                17.8948  2019      8
# 2019-10-01     4                18.0950  2019     10
# 2020-03-01     5                18.1830  2020      3

# %%
df_usa_KWT.groupby('Year').sum()
# Out:
# ID    Rank  Sirloin steak per kg.  Month
# Year
# 2019    97               220.2310     78
# 2020   211               232.9019     78
# 2021   358               269.8421     78

# %% [markdown]
# <p style="color:green;"> *Continuation of this test will continue in the report appendix 2.<br>

# %% [markdown]
# #### 4. Mann-Whitney U test

# %%
df_usa_year['Country']='USA'
df_irl_year['Country']='IRL'
#get 'Sirloin steak per kg.' columns from df_usa_year and df_year_year into one DataFrame
df_MannWT=df_usa_year.append(df_irl_year).sort_values('Sirloin steak per kg.')
#add ranks to each observation
df_MannWT.insert(0, 'Rank', range(1, 1 + len(df_MannWT)))
df_MannWT.head()
# Out:
# ID    Rank  Sirloin steak per kg.  Month Country
# Year
# 1997     1               8.315500    6.5     IRL
# 1998     2               8.336583    6.5     IRL
# 1999     3               8.464167    6.5     IRL
# 2000     4               9.175833    6.5     IRL
# 1998     5               9.216350    6.5     USA

# %%
df_MannWT.groupby('Country').sum()
# Out:
# ID       Rank  Sirloin steak per kg.  Month
# Country
# IRL       600             334.004250  162.5
# USA       675             362.505183  162.5

# %%
#use boxplot to check how data is spread
import matplotlib.pyplot as plt
sns.boxplot(x=df_MannWT.Country, y=df_MannWT['Sirloin steak per kg.'])
plt.show()

# %%
import scipy.stats as stats
#Check data distributions using Shapiro-Wilk test
w, pvalue = stats.shapiro(df_irl_year['Sirloin steak per kg.'])
print('IRL: ',w, pvalue)

w, pvalue = stats.shapiro(df_usa_year['Sirloin steak per kg.'])
print('USA: ',w, pvalue)
#data distribution is not the same
# Out:
# IRL:  0.8619810342788696 0.002999222371727228
# USA:  0.9467272162437439 0.21132934093475342

# %%
# plot histogram
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Frequency histogram of Sirloin steak price')
ax1.hist(df_irl_year['Sirloin steak per kg.'], bins=10, histtype='bar', facecolor = '#6b9c58', edgecolor='#dde26a')
ax2.hist(df_usa_year['Sirloin steak per kg.'], bins=10, histtype='bar', facecolor = '#0A3161', edgecolor='#169acf')
ax1.set_xlabel("Price Ireland")
ax2.set_xlabel("Price USA")
plt.show()

# %% [markdown]
# <p style="color:green;"> *Continuation of this test will continue in the report appendix 3.

# %% [markdown]
# #### 4a. one-sided Mann-Whitney U test

# %%
#perform one-sided Mann-Whitney U test(mean of the USA prices is greater than the mean of the IRL prices) 
import scipy.stats as stats
stats.mannwhitneyu(x=df_usa_year['Sirloin steak per kg.'], y=df_irl_year['Sirloin steak per kg.'], alternative = 'greater')
# Out:
# MannwhitneyuResult(statistic=350.0, pvalue=0.23640779358734065)

# %%
# p value obtained from the Mann-Whitney U test is greater than 0.05 (U = 489.5,0.22 > 0.05), 
#we conclude that the The mean prices of the Sirloin steak in USA are not than the mean prices in the IRL

# %% [markdown]
# ##### 5. Spearman’s r Test

# %%
# calculate the spearman's correlation between mean of the USA prices and the mean of the IRL prices
from scipy.stats import spearmanr
coef, p = spearmanr(df_usa_year['Sirloin steak per kg.'], df_irl_year['Sirloin steak per kg.'])
print('Spearman’s r coefficient: %.3f' % coef)
# interpret the significance
alpha = 0.05
if p > alpha:
    print('No correlation(Accept H0) p= %.3f' % p)
else:
    print('Correlation exists (reject H0) p= %.3f' % p)
# Out:
# Spearman’s r coefficient: 0.792
# Correlation exists (reject H0) p= 0.000

# %%
#prepare dataset for manual calculation of sperman's r test

df_irl_year.rename(columns = {'Sirloin steak per kg.':'Value IRL'}, inplace = True)
df_irl_year.drop(columns=['Month', 'Country'], inplace = True)
df_usa_year.rename(columns = {'Sirloin steak per kg.':'Value USA'}, inplace = True)
df_usa_year.drop(columns=['Month', 'Country'], inplace = True)
df_year = pd.merge(df_irl_year, df_usa_year,on='Year', how='inner')
df_year.head()
# Out:
# ID    Value IRL  Value USA
# Year
# 1997   8.315500   9.255767
# 1998   8.336583   9.216350
# 1999   8.464167   9.611800
# 2000   9.175833  10.401233
# 2001   9.938417  11.598400

# %%
df_year
# Out:
# ID    Value IRL  Value USA
# Year
# 1997   8.315500   9.255767
# 1998   8.336583   9.216350
# 1999   8.464167   9.611800
# 2000   9.175833  10.401233
# 2001   9.938417  11.598400
# 2002  12.545083  11.655967
# 2003  12.700083  13.076067
# 2004  12.883917  14.568583
# 2005  11.846000  13.434483
# 2006  12.971250  13.149400
# 2007  14.280833  13.137300
# 2008  15.260083  13.181667
# 2009  14.441167  12.834433
# 2010  13.620167  12.818300
# 2011  14.173917  13.695183
# 2012  15.495250  14.632750
# 2013  16.347583  15.024900
# 2014  16.191583  16.921300
# 2015  15.903000  18.854733
# 2016  15.745500  18.448650
# 2017  15.652667  17.704867
# 2018  15.018417  18.484033
# 2019  15.164250  18.420967
# 2020  15.191750  19.692200
# 2021  14.341250  22.685850

# %% [markdown]
# #### <p style="color:green;"> *Continuation of this test will continue in the report appendix 4.

# %% [markdown]
# ## Compare Two Datasets

# %%
#compare fwo graphs
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_usa.index,y='Sirloin steak per kg.',data=df_usa,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x=df_irl.index,y='Sirloin steak per kg.',data=df_irl,color='#50C878', linewidth=1.5, label='IRL')
Time_series.set_title('Sirloin steak prices in IRL and USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg/Euro',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
#compare fwo graphs
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_usa.index[:-1],y='difference',data=diff_usa,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x=df_irl.index[:-1],y='difference',data=diff_irl,color='#004F98', linewidth=1.5, label='IRL')
Time_series.set_title('Monthly differences in Sirloin prices in IRL and USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Difference in EURO',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
#crete correlation matrix to check is there a corelation between monthly price difference in USA and IRL
df_diff_corrmat = pd.concat([diff_usa, diff_irl], axis=1, join='inner')
corrmat = df_diff_corrmat.corr()
sns.heatmap(corrmat,annot=True,square=True)
# Out:
# <AxesSubplot:>

# %%
#crete correlation matrix to check is there a corelation between monthly prices in USA and IRL
df_corrmat = pd.concat([df_usa, df_irl], axis=1, join='inner')
corrmat = df_corrmat.corr()
sns.heatmap(corrmat,annot=True,square=True)
# Out:
# <AxesSubplot:xlabel='ID', ylabel='ID'>

# %% [markdown]
# # Machine learning

# %%
df_irl =df_irlML.copy()# return original dataframe structure from the backup file

# %% [markdown]
# ### ARIMA IRL

# %%
#drop unnecessary columns
df_irl.drop(columns=['Year', 'Month'], inplace=True)
df_irl.rename(columns = {'Sirloin steak per kg.':'value'}, inplace = True)
df_irl1 =df_irl.copy()# create copy of the dataframe to use with SARIMAX Model

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_data = seasonal_decompose(df_irl, model="additive")
decompose_data.plot();

# %%
seasonality=decompose_data.seasonal
seasonality.plot(color='green')
# Out:
# <AxesSubplot:xlabel='Daystamp'>

# %%
from statsmodels.tsa.stattools import adfuller
dfadf = adfuller(df_irl['value'], autolag = 'AIC')
print("1. ADF : ",dfadf[0])
print("2. P-Value : ", dfadf[1])
print("5. Critical Values :")
for key, val in dfadf[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -2.211964139506899
# 2. P-Value :  0.201931856024892
# 5. Critical Values :
# 	 1% :  -3.4534232986669546
# 	 5% :  -2.8716994185534745
# 	 10% :  -2.5721833625116144

# %%
rolling_mean = df_irl.rolling(window = 12).mean()
df_irl['rolling_mean_diff'] = rolling_mean - rolling_mean.shift()
ax1 = plt.subplot()
df_irl['rolling_mean_diff'].plot(title='after rolling mean & differencing');
ax2 = plt.subplot()
df_irl.plot(title='original');

# %%
dfadf = adfuller(df_irl['rolling_mean_diff'].dropna(), autolag = 'AIC')
print("1. ADF : ",dfadf[0])
print("2. P-Value : ", dfadf[1])
print("5. Critical Values :")
for key, val in dfadf[4].items():
  print("\t",key, ": ", val)
# Out:
# 1. ADF :  -2.813672330299446
# 2. P-Value :  0.056347157494065735
# 5. Critical Values :
# 	 1% :  -3.4544435065994437
# 	 5% :  -2.8721468827772774
# 	 10% :  -2.572422013959188

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
    # prepare training dataset
    train_size = int(len(X) * 0.90)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(dataset, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
#evaluate_models(df_irl1.values, p_values, d_values, q_values)

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(df_irl['value'],order=(8,0,2))
history=model.fit()
history.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  300
# Model:                     ARMA(8, 2)   Log Likelihood                -213.751
# Method:                       css-mle   S.D. of innovations              0.490
# Date:                Sun, 22 May 2022   AIC                            451.503
# Time:                        16:36:25   BIC                            495.948
# Sample:                    01-01-1997   HQIC                           469.290
#                          - 12-01-2021
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          12.1444      2.264      5.363      0.000       7.706      16.582
# ar.L1.value     0.2817      0.302      0.933      0.351      -0.310       0.873
# ar.L2.value     0.6045      0.315      1.916      0.055      -0.014       1.223
# ar.L3.value     0.1047      0.170      0.618      0.537      -0.228       0.437
# ar.L4.value     0.1178      0.118      0.999      0.318      -0.113       0.349
# ar.L5.value    -0.0088      0.101     -0.087      0.931      -0.207       0.190
# ar.L6.value    -0.0282      0.079     -0.355      0.722      -0.184       0.128
# ar.L7.value     0.0687      0.067      1.032      0.302      -0.062       0.199
# ar.L8.value    -0.1481      0.063     -2.338      0.019      -0.272      -0.024
# ma.L1.value     0.1830      0.305      0.600      0.549      -0.415       0.781
# ma.L2.value    -0.3018      0.299     -1.011      0.312      -0.887       0.283
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1203           -0.3841j            1.1843           -0.4474
# AR.2           -1.1203           +0.3841j            1.1843            0.4474
# AR.3           -0.4622           -1.2499j            1.3326           -0.3064
# AR.4           -0.4622           +1.2499j            1.3326            0.3064
# AR.5            1.0057           -0.0000j            1.0057           -0.0000
# AR.6            1.3034           -0.0000j            1.3034           -0.0000
# AR.7            0.6599           -1.2777j            1.4381           -0.1741
# AR.8            0.6599           +1.2777j            1.4381            0.1741
# MA.1           -1.5422           +0.0000j            1.5422            0.5000
# MA.2            2.1483           +0.0000j            2.1483            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df_irl['forecast']=history.predict(start=200,end=300,dynamic=False)
df_irl[['value','forecast']].plot(figsize=(12,8))
# I would like to add predicted two years to the plot (for 2022 and 2203)
# Out:
# <AxesSubplot:xlabel='Daystamp'>

# %% [markdown]
# ## SARIMAX IRL

# %%
from pmdarima import auto_arima

# %%
auto_arima(df_irl1['value'],seasonal = True, m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  300
# Model:             SARIMAX(2, 1, 3)x(2, 0, [], 12)   Log Likelihood                -205.266
# Date:                             Sun, 22 May 2022   AIC                            426.533
# Time:                                     16:37:01   BIC                            456.136
# Sample:                                          0   HQIC                           438.382
#                                              - 300
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1654      0.153      7.607      0.000       0.865       1.466
# ar.L2         -0.7326      0.129     -5.689      0.000      -0.985      -0.480
# ma.L1         -1.7371      0.159    -10.898      0.000      -2.050      -1.425
# ma.L2          1.4023      0.219      6.394      0.000       0.972       1.832
# ma.L3         -0.3497      0.107     -3.270      0.001      -0.559      -0.140
# ar.S.L12       0.0766      0.053      1.452      0.147      -0.027       0.180
# ar.S.L24       0.1725      0.066      2.600      0.009       0.042       0.303
# sigma2         0.2300      0.012     18.416      0.000       0.205       0.254
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               109.70
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.55   Skew:                            -0.01
# Prob(H) (two-sided):                  0.03   Kurtosis:                         5.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
index_start=len(df_irl1)-36
df_irl1_train = df_irl1.iloc[:index_start]
df_irl1_test = df_irl1.iloc[index_start:]
print(len(df_irl1_train))
print(len(df_irl1_test))
# Out:
# 264
# 36

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(df_irl1['value'], order=(2,1,3), seasonal_order=(2,0,0,12))
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                               value   No. Observations:                  300
# Model:             SARIMAX(2, 1, 3)x(2, 0, [], 12)   Log Likelihood                -205.266
# Date:                             Sun, 22 May 2022   AIC                            426.533
# Time:                                     16:37:02   BIC                            456.136
# Sample:                                 01-01-1997   HQIC                           438.382
#                                       - 12-01-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1654      0.153      7.607      0.000       0.865       1.466
# ar.L2         -0.7326      0.129     -5.689      0.000      -0.985      -0.480
# ma.L1         -1.7371      0.159    -10.898      0.000      -2.050      -1.425
# ma.L2          1.4023      0.219      6.394      0.000       0.972       1.832
# ma.L3         -0.3497      0.107     -3.270      0.001      -0.559      -0.140
# ar.S.L12       0.0766      0.053      1.452      0.147      -0.027       0.180
# ar.S.L24       0.1725      0.066      2.600      0.009       0.042       0.303
# sigma2         0.2300      0.012     18.416      0.000       0.205       0.254
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               109.70
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.55   Skew:                            -0.01
# Prob(H) (two-sided):                  0.03   Kurtosis:                         5.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#save results for dashboard use
result.save('sarima_irl.pkl')

# %%
start = len(df_irl1_train)
end   = len(df_irl1_test)+len(df_irl1_train)+23
predictions = result.predict(start=start, end=end,dynamic=False,type='level')
predictions.plot()
# Out:
# <AxesSubplot:>

# %%
#Visualise prediction
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_irl1.index,y='value',data=df_irl1,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x=predictions.index,y=predictions,data=predictions,color='#50C878', linewidth=1.5, label='IRL')
Time_series.set_title('Sirloin steak prices in IRL and USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg.',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
y_train = df_irl1_train['value']
X_train = df_irl1_train.drop(['value'], axis=1).index.values.reshape(-1, 1)

y_val = df_irl1_test['value']
X_val = df_irl1_test.drop(['value'], axis=1).index.values.reshape(-1, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
import numpy as np

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_val = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential()
model.add(LSTM(100, activation='relu',return_sequences=True)) #LSTM layer
# model.add(LSTM(50, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
# model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam', loss='mae')

# %%
history_lstm = model.fit(X_train,y_train, epochs=500, batch_size=128, verbose=1, shuffle=False, validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 132ms/step - loss: 13.0829 - val_loss: 14.7691
# Epoch 2/500
# 3/3 [==============================] - 0s 17ms/step - loss: 13.0211 - val_loss: 14.6438
# Epoch 3/500
# 3/3 [==============================] - 0s 17ms/step - loss: 12.9136 - val_loss: 14.4292
# Epoch 4/500
# 3/3 [==============================] - 0s 17ms/step - loss: 12.7313 - val_loss: 14.0701
# Epoch 5/500
# 3/3 [==============================] - 0s 17ms/step - loss: 12.4277 - val_loss: 13.4849
# Epoch 6/500
# 3/3 [==============================] - 0s 18ms/step - loss: 11.9395 - val_loss: 12.5644
# Epoch 7/500
# 3/3 [==============================] - 0s 18ms/step - loss: 11.1779 - val_loss: 11.1549
# Epoch 8/500
# 3/3 [==============================] - 0s 17ms/step - loss: 10.0214 - val_loss: 9.0498
# Epoch 9/500
# 3/3 [==============================] - 0s 17ms/step - loss: 8.3082 - val_loss: 5.9753
# Epoch 10/500
# 3/3 [==============================] - 0s 17ms/step - loss: 5.8242 - val_loss: 1.5618
# Epoch 11/500
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3835 - val_loss: 3.5917
# Epoch 12/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4669 - val_loss: 5.1063
# Epoch 13/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.7350 - val_loss: 3.0881
# Epoch 14/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0977 - val_loss: 0.8659
# Epoch 15/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8095 - val_loss: 0.6920
# Epoch 16/500
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1410 - val_loss: 0.6786
# Epoch 17/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5629 - val_loss: 1.7244
# Epoch 18/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1232 - val_loss: 2.4758
# Epoch 19/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0569 - val_loss: 2.3441
# Epoch 20/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0993 - val_loss: 1.6570
# Epoch 21/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2776 - val_loss: 1.0177
# Epoch 22/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4877 - val_loss: 0.8457
# Epoch 23/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5136 - val_loss: 1.0411
# Epoch 24/500
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3564 - val_loss: 1.4709
# Epoch 25/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2354 - val_loss: 1.5667
# Epoch 26/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2313 - val_loss: 1.3877
# Epoch 27/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3058 - val_loss: 1.1492
# Epoch 28/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3749 - val_loss: 1.0417
# Epoch 29/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4044 - val_loss: 1.0268
# Epoch 30/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3993 - val_loss: 1.0726
# Epoch 31/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3688 - val_loss: 1.1727
# Epoch 32/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3259 - val_loss: 1.2913
# Epoch 33/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2828 - val_loss: 1.3307
# Epoch 34/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2864 - val_loss: 1.2606
# Epoch 35/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3041 - val_loss: 1.2316
# Epoch 36/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3079 - val_loss: 1.2352
# Epoch 37/500
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3016 - val_loss: 1.2626
# Epoch 38/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2879 - val_loss: 1.3012
# Epoch 39/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2724 - val_loss: 1.2617
# Epoch 40/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3034 - val_loss: 1.1356
# Epoch 41/500
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3381 - val_loss: 1.0764
# Epoch 42/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3507 - val_loss: 1.0688
# Epoch 43/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3469 - val_loss: 1.0973
# Epoch 44/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3310 - val_loss: 1.1467
# Epoch 45/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3104 - val_loss: 1.2018
# Epoch 46/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2895 - val_loss: 1.2460
# Epoch 47/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2758 - val_loss: 1.2626
# Epoch 48/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2734 - val_loss: 1.2404
# Epoch 49/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2821 - val_loss: 1.1901
# Epoch 50/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2971 - val_loss: 1.1418
# Epoch 51/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3104 - val_loss: 1.1182
# Epoch 52/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3140 - val_loss: 1.1180
# Epoch 53/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3103 - val_loss: 1.1349
# Epoch 54/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3024 - val_loss: 1.1441
# Epoch 55/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3010 - val_loss: 1.1202
# Epoch 56/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3104 - val_loss: 1.0821
# Epoch 57/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3203 - val_loss: 1.0613
# Epoch 58/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3241 - val_loss: 1.0629
# Epoch 59/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3205 - val_loss: 1.0691
# Epoch 60/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3180 - val_loss: 1.0615
# Epoch 61/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3217 - val_loss: 1.0420
# Epoch 62/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3282 - val_loss: 1.0241
# Epoch 63/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3328 - val_loss: 1.0147
# Epoch 64/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.3352 - val_loss: 1.0056
# Epoch 65/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3378 - val_loss: 0.9966
# Epoch 66/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3405 - val_loss: 0.9932
# Epoch 67/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3398 - val_loss: 0.9962
# Epoch 68/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3365 - val_loss: 0.9986
# Epoch 69/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3348 - val_loss: 0.9979
# Epoch 70/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3363 - val_loss: 0.9886
# Epoch 71/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3398 - val_loss: 0.9758
# Epoch 72/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3448 - val_loss: 0.9610
# Epoch 73/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3490 - val_loss: 0.9556
# Epoch 74/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3503 - val_loss: 0.9515
# Epoch 75/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3520 - val_loss: 0.9427
# Epoch 76/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3546 - val_loss: 0.9361
# Epoch 77/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3573 - val_loss: 0.9257
# Epoch 78/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3607 - val_loss: 0.9180
# Epoch 79/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3629 - val_loss: 0.9124
# Epoch 80/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3652 - val_loss: 0.9027
# Epoch 81/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3682 - val_loss: 0.8957
# Epoch 82/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3702 - val_loss: 0.8906
# Epoch 83/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3723 - val_loss: 0.8815
# Epoch 84/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3761 - val_loss: 0.9132
# Epoch 85/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3448 - val_loss: 0.9935
# Epoch 86/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3204 - val_loss: 1.0092
# Epoch 87/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3235 - val_loss: 0.9610
# Epoch 88/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3473 - val_loss: 0.8927
# Epoch 89/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3774 - val_loss: 0.9156
# Epoch 90/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3315 - val_loss: 1.0634
# Epoch 91/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2948 - val_loss: 1.1081
# Epoch 92/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2944 - val_loss: 1.0453
# Epoch 93/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3191 - val_loss: 0.9334
# Epoch 94/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3643 - val_loss: 0.8748
# Epoch 95/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3684 - val_loss: 0.8967
# Epoch 96/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3621 - val_loss: 0.8961
# Epoch 97/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3647 - val_loss: 0.8790
# Epoch 98/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3727 - val_loss: 0.8996
# Epoch 99/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3473 - val_loss: 0.9605
# Epoch 100/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3305 - val_loss: 0.9596
# Epoch 101/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3393 - val_loss: 0.9131
# Epoch 102/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3618 - val_loss: 0.8543
# Epoch 103/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3888 - val_loss: 0.8883
# Epoch 104/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3362 - val_loss: 1.0443
# Epoch 105/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2953 - val_loss: 1.1020
# Epoch 106/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2919 - val_loss: 1.0487
# Epoch 107/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3144 - val_loss: 0.9399
# Epoch 108/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3569 - val_loss: 0.8705
# Epoch 109/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3680 - val_loss: 0.8751
# Epoch 110/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3686 - val_loss: 0.8630
# Epoch 111/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3761 - val_loss: 0.9241
# Epoch 112/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3173 - val_loss: 1.1048
# Epoch 113/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2786 - val_loss: 1.1558
# Epoch 114/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2780 - val_loss: 1.0890
# Epoch 115/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3035 - val_loss: 0.9613
# Epoch 116/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3484 - val_loss: 0.8355
# Epoch 117/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4052 - val_loss: 0.8191
# Epoch 118/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3695 - val_loss: 0.9425
# Epoch 119/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3264 - val_loss: 0.9875
# Epoch 120/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3210 - val_loss: 0.9568
# Epoch 121/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3402 - val_loss: 0.8795
# Epoch 122/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3753 - val_loss: 0.8871
# Epoch 123/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3357 - val_loss: 1.0150
# Epoch 124/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3025 - val_loss: 1.0489
# Epoch 125/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3043 - val_loss: 0.9870
# Epoch 126/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3309 - val_loss: 0.8855
# Epoch 127/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3747 - val_loss: 0.8746
# Epoch 128/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3418 - val_loss: 0.9855
# Epoch 129/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3126 - val_loss: 1.0033
# Epoch 130/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3175 - val_loss: 0.9428
# Epoch 131/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3473 - val_loss: 0.8453
# Epoch 132/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3926 - val_loss: 0.8420
# Epoch 133/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3538 - val_loss: 0.9609
# Epoch 134/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3186 - val_loss: 0.9888
# Epoch 135/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3203 - val_loss: 0.9429
# Epoch 136/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3446 - val_loss: 0.8559
# Epoch 137/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3846 - val_loss: 0.8605
# Epoch 138/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3436 - val_loss: 0.9846
# Epoch 139/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3097 - val_loss: 1.0142
# Epoch 140/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3114 - val_loss: 0.9594
# Epoch 141/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3384 - val_loss: 0.8652
# Epoch 142/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3796 - val_loss: 0.8657
# Epoch 143/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3408 - val_loss: 0.9875
# Epoch 144/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3082 - val_loss: 1.0148
# Epoch 145/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3106 - val_loss: 0.9580
# Epoch 146/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3382 - val_loss: 0.8628
# Epoch 147/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3798 - val_loss: 0.8625
# Epoch 148/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3412 - val_loss: 0.9834
# Epoch 149/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3088 - val_loss: 1.0099
# Epoch 150/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3114 - val_loss: 0.9536
# Epoch 151/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3391 - val_loss: 0.8585
# Epoch 152/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3808 - val_loss: 0.8582
# Epoch 153/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3421 - val_loss: 0.9784
# Epoch 154/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3097 - val_loss: 1.0046
# Epoch 155/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3122 - val_loss: 0.9490
# Epoch 156/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3400 - val_loss: 0.8542
# Epoch 157/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3818 - val_loss: 0.8540
# Epoch 158/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3429 - val_loss: 0.9738
# Epoch 159/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3104 - val_loss: 0.9998
# Epoch 160/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3138 - val_loss: 0.9392
# Epoch 161/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3435 - val_loss: 0.8415
# Epoch 162/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3876 - val_loss: 0.8386
# Epoch 163/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3490 - val_loss: 0.9543
# Epoch 164/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3167 - val_loss: 0.9772
# Epoch 165/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3198 - val_loss: 0.9286
# Epoch 166/500
# 3/3 [==============================] - 0s 21ms/step - loss: 1.3453 - val_loss: 0.8404
# Epoch 167/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3857 - val_loss: 0.8439
# Epoch 168/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3449 - val_loss: 0.9653
# Epoch 169/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3113 - val_loss: 0.9935
# Epoch 170/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3140 - val_loss: 0.9352
# Epoch 171/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3432 - val_loss: 0.8389
# Epoch 172/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3865 - val_loss: 0.8369
# Epoch 173/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3477 - val_loss: 0.9535
# Epoch 174/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3152 - val_loss: 0.9772
# Epoch 175/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3180 - val_loss: 0.9239
# Epoch 176/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3462 - val_loss: 0.8311
# Epoch 177/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3890 - val_loss: 0.8309
# Epoch 178/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3492 - val_loss: 0.9483
# Epoch 179/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3161 - val_loss: 0.9728
# Epoch 180/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3195 - val_loss: 0.9200
# Epoch 181/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3465 - val_loss: 0.8298
# Epoch 182/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3882 - val_loss: 0.8312
# Epoch 183/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3479 - val_loss: 0.9501
# Epoch 184/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3145 - val_loss: 0.9759
# Epoch 185/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3175 - val_loss: 0.9185
# Epoch 186/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3471 - val_loss: 0.8239
# Epoch 187/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3911 - val_loss: 0.8220
# Epoch 188/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3517 - val_loss: 0.9365
# Epoch 189/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3191 - val_loss: 0.9646
# Epoch 190/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3199 - val_loss: 0.9177
# Epoch 191/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3451 - val_loss: 0.8310
# Epoch 192/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3860 - val_loss: 0.8300
# Epoch 193/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3479 - val_loss: 0.9409
# Epoch 194/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3172 - val_loss: 0.9655
# Epoch 195/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3193 - val_loss: 0.9159
# Epoch 196/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3454 - val_loss: 0.8278
# Epoch 197/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3871 - val_loss: 0.8256
# Epoch 198/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3492 - val_loss: 0.9349
# Epoch 199/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3188 - val_loss: 0.9586
# Epoch 200/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3211 - val_loss: 0.9087
# Epoch 201/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3474 - val_loss: 0.8618
# Epoch 202/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3528 - val_loss: 0.8517
# Epoch 203/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3653 - val_loss: 0.8826
# Epoch 204/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3232 - val_loss: 1.0144
# Epoch 205/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2913 - val_loss: 1.0432
# Epoch 206/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2957 - val_loss: 0.9704
# Epoch 207/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3258 - val_loss: 0.8579
# Epoch 208/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3754 - val_loss: 0.8264
# Epoch 209/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3517 - val_loss: 0.9090
# Epoch 210/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3305 - val_loss: 0.9183
# Epoch 211/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3355 - val_loss: 0.8714
# Epoch 212/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3602 - val_loss: 0.8730
# Epoch 213/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3295 - val_loss: 0.9755
# Epoch 214/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3048 - val_loss: 0.9796
# Epoch 215/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3147 - val_loss: 0.9064
# Epoch 216/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3496 - val_loss: 0.8429
# Epoch 217/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3612 - val_loss: 0.8620
# Epoch 218/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3432 - val_loss: 0.9004
# Epoch 219/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3382 - val_loss: 0.8750
# Epoch 220/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3553 - val_loss: 0.8492
# Epoch 221/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3536 - val_loss: 0.8528
# Epoch 222/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3608 - val_loss: 0.8905
# Epoch 223/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3174 - val_loss: 1.0228
# Epoch 224/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2874 - val_loss: 1.0471
# Epoch 225/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2930 - val_loss: 0.9702
# Epoch 226/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3242 - val_loss: 0.8605
# Epoch 227/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3714 - val_loss: 0.8330
# Epoch 228/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3461 - val_loss: 0.9207
# Epoch 229/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3234 - val_loss: 0.9330
# Epoch 230/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3275 - val_loss: 0.8880
# Epoch 231/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3512 - val_loss: 0.8481
# Epoch 232/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3544 - val_loss: 0.8852
# Epoch 233/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3303 - val_loss: 0.9373
# Epoch 234/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3208 - val_loss: 0.9161
# Epoch 235/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3375 - val_loss: 0.8463
# Epoch 236/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3718 - val_loss: 0.8446
# Epoch 237/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3378 - val_loss: 0.9481
# Epoch 238/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3102 - val_loss: 0.9606
# Epoch 239/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3174 - val_loss: 0.9000
# Epoch 240/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3476 - val_loss: 0.8468
# Epoch 241/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3554 - val_loss: 0.8741
# Epoch 242/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3346 - val_loss: 0.9191
# Epoch 243/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3275 - val_loss: 0.8982
# Epoch 244/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3429 - val_loss: 0.8321
# Epoch 245/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3759 - val_loss: 0.8418
# Epoch 246/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3361 - val_loss: 0.9562
# Epoch 247/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3049 - val_loss: 0.9779
# Epoch 248/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3095 - val_loss: 0.9167
# Epoch 249/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3402 - val_loss: 0.8199
# Epoch 250/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3850 - val_loss: 0.8173
# Epoch 251/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3456 - val_loss: 0.9321
# Epoch 252/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3126 - val_loss: 0.9607
# Epoch 253/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3133 - val_loss: 0.9142
# Epoch 254/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3385 - val_loss: 0.8279
# Epoch 255/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3792 - val_loss: 0.8278
# Epoch 256/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3404 - val_loss: 0.9410
# Epoch 257/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3089 - val_loss: 0.9618
# Epoch 258/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3133 - val_loss: 0.9073
# Epoch 259/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3412 - val_loss: 0.8577
# Epoch 260/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3475 - val_loss: 0.8461
# Epoch 261/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3606 - val_loss: 0.8762
# Epoch 262/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3182 - val_loss: 1.0079
# Epoch 263/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2858 - val_loss: 1.0369
# Epoch 264/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2901 - val_loss: 0.9653
# Epoch 265/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3203 - val_loss: 0.8582
# Epoch 266/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3667 - val_loss: 0.8327
# Epoch 267/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3415 - val_loss: 0.9168
# Epoch 268/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3201 - val_loss: 0.9265
# Epoch 269/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3250 - val_loss: 0.8798
# Epoch 270/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3494 - val_loss: 0.8822
# Epoch 271/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3184 - val_loss: 0.9878
# Epoch 272/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2933 - val_loss: 0.9936
# Epoch 273/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3028 - val_loss: 0.9193
# Epoch 274/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3371 - val_loss: 0.8151
# Epoch 275/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3852 - val_loss: 0.8078
# Epoch 276/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3473 - val_loss: 0.9171
# Epoch 277/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3153 - val_loss: 0.9431
# Epoch 278/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3159 - val_loss: 0.9006
# Epoch 279/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3398 - val_loss: 0.8596
# Epoch 280/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3430 - val_loss: 0.8542
# Epoch 281/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3535 - val_loss: 0.8856
# Epoch 282/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3121 - val_loss: 1.0119
# Epoch 283/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2831 - val_loss: 1.0319
# Epoch 284/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2895 - val_loss: 0.9562
# Epoch 285/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3206 - val_loss: 0.8523
# Epoch 286/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3665 - val_loss: 0.8285
# Epoch 287/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3395 - val_loss: 0.9198
# Epoch 288/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3153 - val_loss: 0.9298
# Epoch 289/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3214 - val_loss: 0.8811
# Epoch 290/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3464 - val_loss: 0.8824
# Epoch 291/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3157 - val_loss: 0.9874
# Epoch 292/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2908 - val_loss: 0.9927
# Epoch 293/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3004 - val_loss: 0.9183
# Epoch 294/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3348 - val_loss: 0.8141
# Epoch 295/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3829 - val_loss: 0.8070
# Epoch 296/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3449 - val_loss: 0.9167
# Epoch 297/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3127 - val_loss: 0.9431
# Epoch 298/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3131 - val_loss: 0.9010
# Epoch 299/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3369 - val_loss: 0.8195
# Epoch 300/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3758 - val_loss: 0.8270
# Epoch 301/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3335 - val_loss: 0.9475
# Epoch 302/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2996 - val_loss: 0.9747
# Epoch 303/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3022 - val_loss: 0.9181
# Epoch 304/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3314 - val_loss: 0.8236
# Epoch 305/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3753 - val_loss: 0.8188
# Epoch 306/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3372 - val_loss: 0.9329
# Epoch 307/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3046 - val_loss: 0.9557
# Epoch 308/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3074 - val_loss: 0.9088
# Epoch 309/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3328 - val_loss: 0.8230
# Epoch 310/500
# 3/3 [==============================] - 0s 22ms/step - loss: 1.3734 - val_loss: 0.8196
# Epoch 311/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3360 - val_loss: 0.9333
# Epoch 312/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3037 - val_loss: 0.9557
# Epoch 313/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3066 - val_loss: 0.9085
# Epoch 314/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3320 - val_loss: 0.8227
# Epoch 315/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3726 - val_loss: 0.8192
# Epoch 316/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3363 - val_loss: 0.9269
# Epoch 317/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3060 - val_loss: 0.9502
# Epoch 318/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3074 - val_loss: 0.9060
# Epoch 319/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3319 - val_loss: 0.8223
# Epoch 320/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3716 - val_loss: 0.8203
# Epoch 321/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3347 - val_loss: 0.9295
# Epoch 322/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3041 - val_loss: 0.9537
# Epoch 323/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3061 - val_loss: 0.9044
# Epoch 324/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3322 - val_loss: 0.8180
# Epoch 325/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3736 - val_loss: 0.8175
# Epoch 326/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3347 - val_loss: 0.9296
# Epoch 327/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3028 - val_loss: 0.9512
# Epoch 328/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3060 - val_loss: 0.9036
# Epoch 329/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3315 - val_loss: 0.8183
# Epoch 330/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3723 - val_loss: 0.8148
# Epoch 331/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3358 - val_loss: 0.9218
# Epoch 332/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3055 - val_loss: 0.9453
# Epoch 333/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3068 - val_loss: 0.9014
# Epoch 334/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3311 - val_loss: 0.8187
# Epoch 335/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3708 - val_loss: 0.8170
# Epoch 336/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3337 - val_loss: 0.9260
# Epoch 337/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3029 - val_loss: 0.9507
# Epoch 338/500
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3048 - val_loss: 0.9019
# Epoch 339/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3307 - val_loss: 0.8161
# Epoch 340/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3718 - val_loss: 0.8122
# Epoch 341/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3354 - val_loss: 0.9185
# Epoch 342/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3051 - val_loss: 0.9419
# Epoch 343/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3065 - val_loss: 0.8980
# Epoch 344/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3308 - val_loss: 0.8159
# Epoch 345/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3705 - val_loss: 0.8143
# Epoch 346/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3333 - val_loss: 0.9231
# Epoch 347/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3024 - val_loss: 0.9479
# Epoch 348/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3033 - val_loss: 0.9052
# Epoch 349/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3271 - val_loss: 0.8227
# Epoch 350/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3671 - val_loss: 0.8128
# Epoch 351/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3347 - val_loss: 0.9122
# Epoch 352/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3067 - val_loss: 0.9304
# Epoch 353/500
# 3/3 [==============================] - 0s 14ms/step - loss: 1.3099 - val_loss: 0.8884
# Epoch 354/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3324 - val_loss: 0.8511
# Epoch 355/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3344 - val_loss: 0.8483
# Epoch 356/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3439 - val_loss: 0.8821
# Epoch 357/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3014 - val_loss: 1.0119
# Epoch 358/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2716 - val_loss: 1.0290
# Epoch 359/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2796 - val_loss: 0.9502
# Epoch 360/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3115 - val_loss: 0.8452
# Epoch 361/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3577 - val_loss: 0.8175
# Epoch 362/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3335 - val_loss: 0.9021
# Epoch 363/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3110 - val_loss: 0.9143
# Epoch 364/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3150 - val_loss: 0.8703
# Epoch 365/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3384 - val_loss: 0.8755
# Epoch 366/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3062 - val_loss: 0.9838
# Epoch 367/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2801 - val_loss: 0.9928
# Epoch 368/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2886 - val_loss: 0.9209
# Epoch 369/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3217 - val_loss: 0.8182
# Epoch 370/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3675 - val_loss: 0.8095
# Epoch 371/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3322 - val_loss: 0.9175
# Epoch 372/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3009 - val_loss: 0.9426
# Epoch 373/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3017 - val_loss: 0.9003
# Epoch 374/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3254 - val_loss: 0.8189
# Epoch 375/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3645 - val_loss: 0.8145
# Epoch 376/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3287 - val_loss: 0.9253
# Epoch 377/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2969 - val_loss: 0.9466
# Epoch 378/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3001 - val_loss: 0.8993
# Epoch 379/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3255 - val_loss: 0.8150
# Epoch 380/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3650 - val_loss: 0.8174
# Epoch 381/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3261 - val_loss: 0.9306
# Epoch 382/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2939 - val_loss: 0.9533
# Epoch 383/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2966 - val_loss: 0.9018
# Epoch 384/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3246 - val_loss: 0.8126
# Epoch 385/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3660 - val_loss: 0.8118
# Epoch 386/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3274 - val_loss: 0.9272
# Epoch 387/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2939 - val_loss: 0.9523
# Epoch 388/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2958 - val_loss: 0.9026
# Epoch 389/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3232 - val_loss: 0.8144
# Epoch 390/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3639 - val_loss: 0.8106
# Epoch 391/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3277 - val_loss: 0.9213
# Epoch 392/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2957 - val_loss: 0.9432
# Epoch 393/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2987 - val_loss: 0.8965
# Epoch 394/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3239 - val_loss: 0.8130
# Epoch 395/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3631 - val_loss: 0.8120
# Epoch 396/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3258 - val_loss: 0.9254
# Epoch 397/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2930 - val_loss: 0.9491
# Epoch 398/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2953 - val_loss: 0.8985
# Epoch 399/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3230 - val_loss: 0.8105
# Epoch 400/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3641 - val_loss: 0.8103
# Epoch 401/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3252 - val_loss: 0.9262
# Epoch 402/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2916 - val_loss: 0.9518
# Epoch 403/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2932 - val_loss: 0.9028
# Epoch 404/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3203 - val_loss: 0.8150
# Epoch 405/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3617 - val_loss: 0.8066
# Epoch 406/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3275 - val_loss: 0.9128
# Epoch 407/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2968 - val_loss: 0.9372
# Epoch 408/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2977 - val_loss: 0.8948
# Epoch 409/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3214 - val_loss: 0.8143
# Epoch 410/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3602 - val_loss: 0.8103
# Epoch 411/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3252 - val_loss: 0.9152
# Epoch 412/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2953 - val_loss: 0.9381
# Epoch 413/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2967 - val_loss: 0.8947
# Epoch 414/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3208 - val_loss: 0.8136
# Epoch 415/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3598 - val_loss: 0.8092
# Epoch 416/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3240 - val_loss: 0.9196
# Epoch 417/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2921 - val_loss: 0.9415
# Epoch 418/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2950 - val_loss: 0.8951
# Epoch 419/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3201 - val_loss: 0.8121
# Epoch 420/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3600 - val_loss: 0.8065
# Epoch 421/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3246 - val_loss: 0.9153
# Epoch 422/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2930 - val_loss: 0.9417
# Epoch 423/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2931 - val_loss: 0.8957
# Epoch 424/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3193 - val_loss: 0.8110
# Epoch 425/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3599 - val_loss: 0.8042
# Epoch 426/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3250 - val_loss: 0.9116
# Epoch 427/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2936 - val_loss: 0.9374
# Epoch 428/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2941 - val_loss: 0.8961
# Epoch 429/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3174 - val_loss: 0.8162
# Epoch 430/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3555 - val_loss: 0.8131
# Epoch 431/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3204 - val_loss: 0.9194
# Epoch 432/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2901 - val_loss: 0.9380
# Epoch 433/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2941 - val_loss: 0.8894
# Epoch 434/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3200 - val_loss: 0.8461
# Epoch 435/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3241 - val_loss: 0.8397
# Epoch 436/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3348 - val_loss: 0.8708
# Epoch 437/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2928 - val_loss: 0.9970
# Epoch 438/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2629 - val_loss: 1.0135
# Epoch 439/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2708 - val_loss: 0.9388
# Epoch 440/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3025 - val_loss: 0.8360
# Epoch 441/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3483 - val_loss: 0.8103
# Epoch 442/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3225 - val_loss: 0.9019
# Epoch 443/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2969 - val_loss: 0.9206
# Epoch 444/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2985 - val_loss: 0.8820
# Epoch 445/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3198 - val_loss: 0.8482
# Epoch 446/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3205 - val_loss: 0.8484
# Epoch 447/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3286 - val_loss: 0.8423
# Epoch 448/500
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3195 - val_loss: 0.8615
# Epoch 449/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3203 - val_loss: 0.8277
# Epoch 450/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3409 - val_loss: 0.8477
# Epoch 451/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3012 - val_loss: 0.9679
# Epoch 452/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2687 - val_loss: 0.9967
# Epoch 453/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2716 - val_loss: 0.9368
# Epoch 454/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2999 - val_loss: 0.8417
# Epoch 455/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3425 - val_loss: 0.8208
# Epoch 456/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3148 - val_loss: 0.9191
# Epoch 457/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2877 - val_loss: 0.9361
# Epoch 458/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2910 - val_loss: 0.8887
# Epoch 459/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3164 - val_loss: 0.8465
# Epoch 460/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3201 - val_loss: 0.8412
# Epoch 461/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3304 - val_loss: 0.8735
# Epoch 462/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2880 - val_loss: 1.0019
# Epoch 463/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2574 - val_loss: 1.0200
# Epoch 464/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2649 - val_loss: 0.9445
# Epoch 465/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2965 - val_loss: 0.8420
# Epoch 466/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3418 - val_loss: 0.8166
# Epoch 467/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3159 - val_loss: 0.9104
# Epoch 468/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2897 - val_loss: 0.9248
# Epoch 469/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2940 - val_loss: 0.8810
# Epoch 470/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3171 - val_loss: 0.8439
# Epoch 471/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3180 - val_loss: 0.8475
# Epoch 472/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3248 - val_loss: 0.8440
# Epoch 473/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3137 - val_loss: 0.8718
# Epoch 474/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3116 - val_loss: 0.8429
# Epoch 475/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3296 - val_loss: 0.8679
# Epoch 476/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2884 - val_loss: 0.9908
# Epoch 477/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2579 - val_loss: 1.0190
# Epoch 478/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2616 - val_loss: 0.9519
# Epoch 479/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2904 - val_loss: 0.8494
# Epoch 480/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3355 - val_loss: 0.8228
# Epoch 481/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3113 - val_loss: 0.9151
# Epoch 482/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2859 - val_loss: 0.9277
# Epoch 483/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2907 - val_loss: 0.8775
# Epoch 484/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3173 - val_loss: 0.8344
# Epoch 485/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3198 - val_loss: 0.8390
# Epoch 486/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3241 - val_loss: 0.8474
# Epoch 487/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3084 - val_loss: 0.8850
# Epoch 488/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3030 - val_loss: 0.8617
# Epoch 489/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3191 - val_loss: 0.8400
# Epoch 490/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3140 - val_loss: 0.8593
# Epoch 491/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3145 - val_loss: 0.8259
# Epoch 492/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3343 - val_loss: 0.8521
# Epoch 493/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2908 - val_loss: 0.9862
# Epoch 494/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2545 - val_loss: 1.0301
# Epoch 495/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2544 - val_loss: 0.9695
# Epoch 496/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2802 - val_loss: 0.8661
# Epoch 497/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3264 - val_loss: 0.8324
# Epoch 498/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3050 - val_loss: 0.9208
# Epoch 499/500
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2813 - val_loss: 0.9300
# Epoch 500/500
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2872 - val_loss: 0.8774

# %%
history_lstm.history['loss'][-1], history_lstm.history['val_loss'][-1]
# Out:
# (1.2871860265731812, 0.8773720264434814)

# %%
from dateutil.relativedelta import relativedelta

test_values = df_irl1_test.index.to_list()
future_month = []
for i in range(1, 13):
    test_values.append(df_irl1_test.index[-1] + relativedelta(months=i))
    
X_test = scaler.transform(pd.to_datetime(test_values).values.reshape(-1, 1))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
lstm_pred = model.predict(X_test)
lstm_predictions = pd.DataFrame({'datetime':pd.to_datetime(test_values), 'lstm_pred':lstm_pred.flatten()})

# %%
#Visualise prediction
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_irl1.index,y='value',data=df_irl1,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x="datetime",y="lstm_pred",data=lstm_predictions,color='#50C878', linewidth=1.5, label='IRL')
Time_series.set_title('Sirloin steak prices in IRL and USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg.',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %% [markdown]
# ## ARIMA USA

# %%
df_usa =df_usaML.copy()# return original dataframe structure from the backup file

# %%
#drop unnecessary columns
df_usa.drop(columns=['Year', 'Month'], inplace=True)
df_usa.rename(columns = {'Sirloin steak per kg.':'value'}, inplace = True)
df_usa1 =df_usa.copy()# create copy of the dataframe to use with SARIMAX Model

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_data = seasonal_decompose(df_usa, model="additive")
decompose_data.plot();

# %%
seasonality=decompose_data.seasonal
seasonality.plot(color='green')
# Out:
# <AxesSubplot:xlabel='Daystamp'>

# %%
from statsmodels.tsa.stattools import adfuller
dfadf = adfuller(df_usa['value'], autolag = 'AIC')
print("1. ADF : ",dfadf[0])
print("2. P-Value : ", dfadf[1])
print("5. Critical Values :")
for key, val in dfadf[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  1.0152746841790639
# 2. P-Value :  0.9944245280812213
# 5. Critical Values :
# 	 1% :  -3.452713099849546
# 	 5% :  -2.871387839457783
# 	 10% :  -2.5720171933352485

# %%
rolling_mean = df_usa.rolling(window = 12).mean()
df_usa['rolling_mean_diff'] = rolling_mean - rolling_mean.shift()
ax1 = plt.subplot()
df_usa['rolling_mean_diff'].plot(title='after rolling mean & differencing');
ax2 = plt.subplot()
df_usa.plot(title='original');

# %%
dfadf = adfuller(df_usa['rolling_mean_diff'].dropna(), autolag = 'AIC')
print("1. ADF : ",dfadf[0])
print("2. P-Value : ", dfadf[1])
print("5. Critical Values :")
for key, val in dfadf[4].items():
  print("\t",key, ": ", val)
# Out:
# 1. ADF :  -2.206490108365217
# 2. P-Value :  0.2038983603536953
# 5. Critical Values :
# 	 1% :  -3.4544435065994437
# 	 5% :  -2.8721468827772774
# 	 10% :  -2.572422013959188

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
    # prepare training dataset
    train_size = int(len(X) * 0.60)
    train, test = X[0:train_size], X[train_size:]
    history = [x for x in train]
    # make predictions
    predictions = list()
    for t in range(len(test)):
        model = ARIMA(history, order=arima_order)
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        predictions.append(yhat)
        history.append(test[t])
    # calculate out of sample error
    rmse = sqrt(mean_squared_error(test, predictions))
    return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
    dataset = dataset.astype('float32')
    best_score, best_cfg = float("inf"), None
    for p in p_values:
        for d in d_values:
            for q in q_values:
                order = (p,d,q)
                try:
                    rmse = evaluate_arima_model(dataset, order)
                    if rmse < best_score:
                        best_score, best_cfg = rmse, order
                    print('ARIMA%s RMSE=%.3f' % (order,rmse))
                except:
                    continue
    print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
#evaluate_models(df_usa1.values, p_values, d_values, q_values)

# %%
from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(df_usa['value'],order=(4, 2, 1))
history=model.fit()
history.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.value   No. Observations:                  298
# Model:                 ARIMA(4, 2, 1)   Log Likelihood                -196.409
# Method:                       css-mle   S.D. of innovations              0.463
# Date:                Sun, 22 May 2022   AIC                            406.818
# Time:                        16:37:29   BIC                            432.698
# Sample:                    03-01-1997   HQIC                           417.178
#                          - 12-01-2021
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0003      0.000      1.433      0.152      -0.000       0.001
# ar.L1.D2.value    -0.3155      0.057     -5.496      0.000      -0.428      -0.203
# ar.L2.D2.value     0.0707      0.061      1.153      0.249      -0.049       0.191
# ar.L3.D2.value     0.0145      0.061      0.237      0.813      -0.106       0.135
# ar.L4.D2.value    -0.1426      0.059     -2.419      0.016      -0.258      -0.027
# ma.L1.D2.value    -1.0000      0.013    -79.125      0.000      -1.025      -0.975
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1884           -0.8792j            1.4783           -0.3986
# AR.2           -1.1884           +0.8792j            1.4783            0.3986
# AR.3            1.2392           -1.2939j            1.7916           -0.1284
# AR.4            1.2392           +1.2939j            1.7916            0.1284
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df_usa['forecast']=history.predict(start=250,end=300,dynamic=False)
df_usa[['value','forecast']].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Daystamp'>

# %% [markdown]
# ### SARIMAX USA

# %%
auto_arima(df_usa1['value'],seasonal = True, m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  300
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -198.051
# Date:                Sun, 22 May 2022   AIC                            402.103
# Time:                        16:37:31   BIC                            413.204
# Sample:                             0   HQIC                           406.546
#                                 - 300
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0691      0.029      2.365      0.018       0.012       0.126
# ar.L1         -0.3331      0.039     -8.501      0.000      -0.410      -0.256
# sigma2         0.2201      0.011     20.354      0.000       0.199       0.241
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):               283.10
# Prob(Q):                              0.79   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.72   Skew:                             0.89
# Prob(H) (two-sided):                  0.01   Kurtosis:                         7.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
index_start=len(df_usa1)-36
df_usa1_train = df_usa1.iloc[:index_start]
df_usa1_test = df_usa1.iloc[index_start:]
print(len(df_usa1_train))
print(len(df_usa1_test))
# Out:
# 264
# 36

# %%
model = SARIMAX(df_usa1['value'], order=(4,2,1))
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                  300
# Model:               SARIMAX(4, 2, 1)   Log Likelihood                -197.254
# Date:                Sun, 22 May 2022   AIC                            406.508
# Time:                        16:37:31   BIC                            428.690
# Sample:                    01-01-1997   HQIC                           415.387
#                          - 12-01-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3160      0.043     -7.315      0.000      -0.401      -0.231
# ar.L2          0.0699      0.066      1.051      0.293      -0.060       0.200
# ar.L3          0.0141      0.062      0.225      0.822      -0.108       0.136
# ar.L4         -0.1429      0.054     -2.629      0.009      -0.249      -0.036
# ma.L1         -0.9870      0.019    -52.957      0.000      -1.024      -0.950
# sigma2         0.2167      0.011     19.280      0.000       0.195       0.239
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               242.29
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.60   Skew:                             0.73
# Prob(H) (two-sided):                  0.02   Kurtosis:                         7.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#save results for dashboard use
result.save('sarima_usa.pkl')

# %%
start = len(df_usa1_train)
end   = len(df_usa1_test)+len(df_usa1_train)+23
predictions = result.predict(start=start, end=end,dynamic=False,type='level')
predictions.plot()
# Out:
# <AxesSubplot:>

# %%
#Visualise prediction
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_usa1.index,y='value',data=df_usa1,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x=predictions.index,y=predictions,data=predictions,color='#50C878', linewidth=1.5, label='USA predicted')
Time_series.set_title('Sirloin steak prices in USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg.',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()

# %%
y_train = df_usa1_train['value']
X_train = df_usa1_train.drop(['value'], axis=1).index.values.reshape(-1, 1)

y_val = df_usa1_test['value']
X_val = df_usa1_test.drop(['value'], axis=1).index.values.reshape(-1, 1)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_val = np.reshape(X_val, (X_val.shape[0], 1, X_val.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, activation='relu',return_sequences=True)) #LSTM layer
# model.add(LSTM(50, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
# model.add(Dense(32, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='Adam', loss='mae')

# %%
history_lstm = model.fit(X_train,y_train, epochs=500, batch_size=128, verbose=1, shuffle=False, validation_data=(X_val, y_val))
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 188ms/step - loss: 13.6322 - val_loss: 19.9767
# Epoch 2/500
# 3/3 [==============================] - 0s 18ms/step - loss: 13.5525 - val_loss: 19.8164
# Epoch 3/500
# 3/3 [==============================] - 0s 19ms/step - loss: 13.4143 - val_loss: 19.5417
# Epoch 4/500
# 3/3 [==============================] - 0s 17ms/step - loss: 13.1765 - val_loss: 19.0774
# Epoch 5/500
# 3/3 [==============================] - 0s 19ms/step - loss: 12.7807 - val_loss: 18.3266
# Epoch 6/500
# 3/3 [==============================] - 0s 17ms/step - loss: 12.1492 - val_loss: 17.1590
# Epoch 7/500
# 3/3 [==============================] - 0s 17ms/step - loss: 11.1760 - val_loss: 15.3919
# Epoch 8/500
# 3/3 [==============================] - 0s 18ms/step - loss: 9.7146 - val_loss: 12.7793
# Epoch 9/500
# 3/3 [==============================] - 0s 20ms/step - loss: 7.5707 - val_loss: 8.9923
# Epoch 10/500
# 3/3 [==============================] - 0s 18ms/step - loss: 4.4847 - val_loss: 3.5957
# Epoch 11/500
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1965 - val_loss: 2.2266
# Epoch 12/500
# 3/3 [==============================] - 0s 18ms/step - loss: 2.9180 - val_loss: 2.0274
# Epoch 13/500
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1350 - val_loss: 1.7574
# Epoch 14/500
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0711 - val_loss: 3.9341
# Epoch 15/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5296 - val_loss: 3.7092
# Epoch 16/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2042 - val_loss: 1.8978
# Epoch 17/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0756 - val_loss: 1.3675
# Epoch 18/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.5878 - val_loss: 1.3043
# Epoch 19/500
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2400 - val_loss: 2.0637
# Epoch 20/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9727 - val_loss: 2.2362
# Epoch 21/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9625 - val_loss: 1.5664
# Epoch 22/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0302 - val_loss: 1.3202
# Epoch 23/500
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1211 - val_loss: 1.4099
# Epoch 24/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9926 - val_loss: 1.5289
# Epoch 25/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9409 - val_loss: 1.3183
# Epoch 26/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0548 - val_loss: 1.2727
# Epoch 27/500
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0307 - val_loss: 1.4310
# Epoch 28/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8847 - val_loss: 1.6001
# Epoch 29/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8984 - val_loss: 1.2711
# Epoch 30/500
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0289 - val_loss: 1.3269
# Epoch 31/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9624 - val_loss: 1.4238
# Epoch 32/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8778 - val_loss: 1.4914
# Epoch 33/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9149 - val_loss: 1.2672
# Epoch 34/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9350 - val_loss: 1.2523
# Epoch 35/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9064 - val_loss: 1.3494
# Epoch 36/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8780 - val_loss: 1.3933
# Epoch 37/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9255 - val_loss: 1.2550
# Epoch 38/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9191 - val_loss: 1.2797
# Epoch 39/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8809 - val_loss: 1.3140
# Epoch 40/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9185 - val_loss: 1.2623
# Epoch 41/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8998 - val_loss: 1.3455
# Epoch 42/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8805 - val_loss: 1.3499
# Epoch 43/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9321 - val_loss: 1.2564
# Epoch 44/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - val_loss: 1.2732
# Epoch 45/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8779 - val_loss: 1.3348
# Epoch 46/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9098 - val_loss: 1.2904
# Epoch 47/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8897 - val_loss: 1.3259
# Epoch 48/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8934 - val_loss: 1.3302
# Epoch 49/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8888 - val_loss: 1.2717
# Epoch 50/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9492 - val_loss: 1.2528
# Epoch 51/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8801 - val_loss: 1.3537
# Epoch 52/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8977 - val_loss: 1.3120
# Epoch 53/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8953 - val_loss: 1.3259
# Epoch 54/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8861 - val_loss: 1.2835
# Epoch 55/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9398 - val_loss: 1.2524
# Epoch 56/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8922 - val_loss: 1.3505
# Epoch 57/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8841 - val_loss: 1.2854
# Epoch 58/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9610 - val_loss: 1.2522
# Epoch 59/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8789 - val_loss: 1.3721
# Epoch 60/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8962 - val_loss: 1.2778
# Epoch 61/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9391 - val_loss: 1.2515
# Epoch 62/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8915 - val_loss: 1.3793
# Epoch 63/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8856 - val_loss: 1.3531
# Epoch 64/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9363 - val_loss: 1.2688
# Epoch 65/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9446 - val_loss: 1.2627
# Epoch 66/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8792 - val_loss: 1.3361
# Epoch 67/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9071 - val_loss: 1.3026
# Epoch 68/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8854 - val_loss: 1.2842
# Epoch 69/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9360 - val_loss: 1.2545
# Epoch 70/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9157 - val_loss: 1.3326
# Epoch 71/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8750 - val_loss: 1.3722
# Epoch 72/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9267 - val_loss: 1.2514
# Epoch 73/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9212 - val_loss: 1.2920
# Epoch 74/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8764 - val_loss: 1.3117
# Epoch 75/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9338 - val_loss: 1.2585
# Epoch 76/500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9254 - val_loss: 1.3060
# Epoch 77/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8725 - val_loss: 1.3495
# Epoch 78/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9269 - val_loss: 1.2508
# Epoch 79/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9190 - val_loss: 1.3018
# Epoch 80/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8750 - val_loss: 1.3258
# Epoch 81/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9328 - val_loss: 1.2562
# Epoch 82/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9270 - val_loss: 1.2920
# Epoch 83/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8739 - val_loss: 1.3335
# Epoch 84/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9284 - val_loss: 1.2504
# Epoch 85/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9205 - val_loss: 1.3003
# Epoch 86/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8746 - val_loss: 1.3290
# Epoch 87/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9321 - val_loss: 1.2537
# Epoch 88/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9242 - val_loss: 1.2968
# Epoch 89/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8736 - val_loss: 1.3354
# Epoch 90/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9290 - val_loss: 1.2505
# Epoch 91/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9218 - val_loss: 1.2959
# Epoch 92/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8744 - val_loss: 1.3265
# Epoch 93/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9324 - val_loss: 1.2543
# Epoch 94/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9244 - val_loss: 1.2964
# Epoch 95/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8738 - val_loss: 1.3320
# Epoch 96/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9303 - val_loss: 1.2506
# Epoch 97/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9219 - val_loss: 1.2964
# Epoch 98/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8745 - val_loss: 1.3253
# Epoch 99/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9330 - val_loss: 1.2556
# Epoch 100/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9259 - val_loss: 1.2929
# Epoch 101/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8735 - val_loss: 1.3317
# Epoch 102/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9298 - val_loss: 1.2503
# Epoch 103/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9206 - val_loss: 1.2998
# Epoch 104/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8744 - val_loss: 1.3299
# Epoch 105/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9318 - val_loss: 1.2526
# Epoch 106/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9228 - val_loss: 1.2989
# Epoch 107/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8737 - val_loss: 1.3344
# Epoch 108/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9298 - val_loss: 1.2506
# Epoch 109/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9229 - val_loss: 1.2930
# Epoch 110/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8742 - val_loss: 1.3243
# Epoch 111/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9328 - val_loss: 1.2550
# Epoch 112/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9247 - val_loss: 1.2947
# Epoch 113/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8736 - val_loss: 1.3307
# Epoch 114/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9306 - val_loss: 1.2504
# Epoch 115/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9220 - val_loss: 1.2951
# Epoch 116/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8744 - val_loss: 1.3242
# Epoch 117/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9333 - val_loss: 1.2558
# Epoch 118/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9258 - val_loss: 1.2918
# Epoch 119/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8733 - val_loss: 1.3307
# Epoch 120/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9301 - val_loss: 1.2499
# Epoch 121/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9205 - val_loss: 1.2987
# Epoch 122/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8742 - val_loss: 1.3288
# Epoch 123/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9320 - val_loss: 1.2528
# Epoch 124/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9226 - val_loss: 1.2977
# Epoch 125/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8736 - val_loss: 1.3333
# Epoch 126/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9301 - val_loss: 1.2504
# Epoch 127/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9236 - val_loss: 1.2896
# Epoch 128/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8745 - val_loss: 1.3224
# Epoch 129/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - val_loss: 1.2543
# Epoch 130/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9234 - val_loss: 1.2973
# Epoch 131/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8734 - val_loss: 1.3347
# Epoch 132/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9294 - val_loss: 1.2498
# Epoch 133/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9218 - val_loss: 1.2930
# Epoch 134/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8744 - val_loss: 1.3195
# Epoch 135/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9341 - val_loss: 1.2578
# Epoch 136/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9273 - val_loss: 1.2884
# Epoch 137/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8733 - val_loss: 1.3307
# Epoch 138/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9290 - val_loss: 1.2494
# Epoch 139/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9199 - val_loss: 1.2979
# Epoch 140/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8742 - val_loss: 1.3272
# Epoch 141/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9325 - val_loss: 1.2535
# Epoch 142/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9231 - val_loss: 1.2949
# Epoch 143/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8735 - val_loss: 1.3302
# Epoch 144/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9307 - val_loss: 1.2498
# Epoch 145/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9216 - val_loss: 1.2935
# Epoch 146/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8742 - val_loss: 1.3223
# Epoch 147/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9337 - val_loss: 1.2562
# Epoch 148/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9259 - val_loss: 1.2895
# Epoch 149/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8731 - val_loss: 1.3281
# Epoch 150/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9305 - val_loss: 1.2496
# Epoch 151/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9208 - val_loss: 1.2958
# Epoch 152/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8740 - val_loss: 1.3259
# Epoch 153/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9325 - val_loss: 1.2536
# Epoch 154/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9230 - val_loss: 1.2946
# Epoch 155/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8733 - val_loss: 1.3302
# Epoch 156/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9305 - val_loss: 1.2495
# Epoch 157/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9213 - val_loss: 1.2938
# Epoch 158/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8740 - val_loss: 1.3227
# Epoch 159/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9334 - val_loss: 1.2557
# Epoch 160/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9253 - val_loss: 1.2899
# Epoch 161/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8733 - val_loss: 1.3249
# Epoch 162/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9317 - val_loss: 1.2520
# Epoch 163/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9225 - val_loss: 1.2929
# Epoch 164/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8736 - val_loss: 1.3254
# Epoch 165/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9321 - val_loss: 1.2527
# Epoch 166/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9224 - val_loss: 1.2939
# Epoch 167/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8734 - val_loss: 1.3282
# Epoch 168/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9311 - val_loss: 1.2503
# Epoch 169/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9223 - val_loss: 1.2902
# Epoch 170/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8740 - val_loss: 1.3187
# Epoch 171/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9337 - val_loss: 1.2564
# Epoch 172/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9253 - val_loss: 1.2893
# Epoch 173/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8731 - val_loss: 1.3254
# Epoch 174/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9313 - val_loss: 1.2508
# Epoch 175/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9225 - val_loss: 1.2897
# Epoch 176/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8739 - val_loss: 1.3189
# Epoch 177/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9341 - val_loss: 1.2573
# Epoch 178/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9263 - val_loss: 1.2869
# Epoch 179/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8734 - val_loss: 1.3250
# Epoch 180/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9306 - val_loss: 1.2494
# Epoch 181/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9204 - val_loss: 1.2949
# Epoch 182/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8736 - val_loss: 1.3258
# Epoch 183/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9321 - val_loss: 1.2526
# Epoch 184/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9225 - val_loss: 1.2924
# Epoch 185/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8733 - val_loss: 1.3262
# Epoch 186/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9314 - val_loss: 1.2513
# Epoch 187/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9219 - val_loss: 1.2923
# Epoch 188/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8734 - val_loss: 1.3243
# Epoch 189/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9321 - val_loss: 1.2529
# Epoch 190/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9225 - val_loss: 1.2920
# Epoch 191/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8732 - val_loss: 1.3262
# Epoch 192/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9313 - val_loss: 1.2509
# Epoch 193/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9220 - val_loss: 1.2902
# Epoch 194/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8736 - val_loss: 1.3205
# Epoch 195/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9333 - val_loss: 1.2554
# Epoch 196/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9244 - val_loss: 1.2891
# Epoch 197/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8730 - val_loss: 1.3245
# Epoch 198/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9313 - val_loss: 1.2509
# Epoch 199/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9218 - val_loss: 1.2904
# Epoch 200/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8735 - val_loss: 1.3212
# Epoch 201/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9329 - val_loss: 1.2546
# Epoch 202/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9232 - val_loss: 1.2903
# Epoch 203/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3262
# Epoch 204/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9309 - val_loss: 1.2497
# Epoch 205/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9212 - val_loss: 1.2898
# Epoch 206/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8736 - val_loss: 1.3189
# Epoch 207/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9337 - val_loss: 1.2563
# Epoch 208/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9251 - val_loss: 1.2865
# Epoch 209/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3210
# Epoch 210/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9321 - val_loss: 1.2526
# Epoch 211/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9232 - val_loss: 1.2868
# Epoch 212/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8736 - val_loss: 1.3205
# Epoch 213/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9320 - val_loss: 1.2524
# Epoch 214/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9229 - val_loss: 1.2875
# Epoch 215/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8733 - val_loss: 1.3181
# Epoch 216/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9333 - val_loss: 1.2557
# Epoch 217/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9243 - val_loss: 1.2879
# Epoch 218/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8728 - val_loss: 1.3235
# Epoch 219/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9312 - val_loss: 1.2507
# Epoch 220/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9213 - val_loss: 1.2897
# Epoch 221/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8733 - val_loss: 1.3206
# Epoch 222/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9327 - val_loss: 1.2542
# Epoch 223/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9234 - val_loss: 1.2874
# Epoch 224/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3207
# Epoch 225/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9321 - val_loss: 1.2529
# Epoch 226/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9228 - val_loss: 1.2872
# Epoch 227/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8731 - val_loss: 1.3186
# Epoch 228/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9329 - val_loss: 1.2546
# Epoch 229/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9234 - val_loss: 1.2868
# Epoch 230/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3203
# Epoch 231/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9321 - val_loss: 1.2527
# Epoch 232/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9230 - val_loss: 1.2851
# Epoch 233/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8735 - val_loss: 1.3180
# Epoch 234/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9323 - val_loss: 1.2532
# Epoch 235/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9227 - val_loss: 1.2870
# Epoch 236/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8730 - val_loss: 1.3192
# Epoch 237/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9325 - val_loss: 1.2537
# Epoch 238/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9235 - val_loss: 1.2849
# Epoch 239/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8732 - val_loss: 1.3190
# Epoch 240/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9317 - val_loss: 1.2520
# Epoch 241/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9220 - val_loss: 1.2871
# Epoch 242/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8730 - val_loss: 1.3180
# Epoch 243/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9329 - val_loss: 1.2548
# Epoch 244/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9237 - val_loss: 1.2856
# Epoch 245/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8727 - val_loss: 1.3187
# Epoch 246/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9322 - val_loss: 1.2533
# Epoch 247/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9229 - val_loss: 1.2855
# Epoch 248/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3167
# Epoch 249/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9330 - val_loss: 1.2550
# Epoch 250/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9236 - val_loss: 1.2851
# Epoch 251/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8727 - val_loss: 1.3183
# Epoch 252/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9322 - val_loss: 1.2531
# Epoch 253/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9226 - val_loss: 1.2853
# Epoch 254/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3166
# Epoch 255/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9330 - val_loss: 1.2547
# Epoch 256/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9242 - val_loss: 1.2819
# Epoch 257/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8732 - val_loss: 1.3152
# Epoch 258/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9324 - val_loss: 1.2534
# Epoch 259/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9230 - val_loss: 1.2836
# Epoch 260/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8732 - val_loss: 1.3173
# Epoch 261/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2523
# Epoch 262/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9221 - val_loss: 1.2853
# Epoch 263/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3157
# Epoch 264/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9332 - val_loss: 1.2554
# Epoch 265/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9241 - val_loss: 1.2835
# Epoch 266/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8728 - val_loss: 1.3196
# Epoch 267/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9307 - val_loss: 1.2500
# Epoch 268/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9205 - val_loss: 1.2877
# Epoch 269/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3178
# Epoch 270/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - val_loss: 1.2546
# Epoch 271/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9238 - val_loss: 1.2836
# Epoch 272/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8728 - val_loss: 1.3187
# Epoch 273/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9309 - val_loss: 1.2509
# Epoch 274/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9208 - val_loss: 1.2879
# Epoch 275/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8727 - val_loss: 1.3195
# Epoch 276/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9318 - val_loss: 1.2530
# Epoch 277/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.9229 - val_loss: 1.2840
# Epoch 278/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3177
# Epoch 279/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9313 - val_loss: 1.2520
# Epoch 280/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9213 - val_loss: 1.2875
# Epoch 281/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8725 - val_loss: 1.3203
# Epoch 282/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9313 - val_loss: 1.2519
# Epoch 283/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9217 - val_loss: 1.2859
# Epoch 284/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8726 - val_loss: 1.3169
# Epoch 285/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9323 - val_loss: 1.2542
# Epoch 286/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9239 - val_loss: 1.2816
# Epoch 287/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8728 - val_loss: 1.3147
# Epoch 288/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9312 - val_loss: 1.2520
# Epoch 289/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9206 - val_loss: 1.2883
# Epoch 290/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8727 - val_loss: 1.3189
# Epoch 291/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2531
# Epoch 292/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9228 - val_loss: 1.2824
# Epoch 293/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8728 - val_loss: 1.3153
# Epoch 294/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9317 - val_loss: 1.2528
# Epoch 295/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9217 - val_loss: 1.2851
# Epoch 296/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8724 - val_loss: 1.3172
# Epoch 297/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2530
# Epoch 298/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9223 - val_loss: 1.2831
# Epoch 299/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8725 - val_loss: 1.3134
# Epoch 300/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9330 - val_loss: 1.2556
# Epoch 301/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9246 - val_loss: 1.2787
# Epoch 302/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8728 - val_loss: 1.3111
# Epoch 303/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2532
# Epoch 304/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9213 - val_loss: 1.2852
# Epoch 305/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8726 - val_loss: 1.3152
# Epoch 306/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2544
# Epoch 307/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9236 - val_loss: 1.2793
# Epoch 308/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8729 - val_loss: 1.3115
# Epoch 309/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9325 - val_loss: 1.2541
# Epoch 310/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9226 - val_loss: 1.2819
# Epoch 311/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8724 - val_loss: 1.3133
# Epoch 312/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2544
# Epoch 313/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9232 - val_loss: 1.2798
# Epoch 314/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8727 - val_loss: 1.3130
# Epoch 315/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2527
# Epoch 316/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9218 - val_loss: 1.2819
# Epoch 317/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8727 - val_loss: 1.3153
# Epoch 318/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9314 - val_loss: 1.2516
# Epoch 319/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9209 - val_loss: 1.2835
# Epoch 320/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8728 - val_loss: 1.3100
# Epoch 321/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.9335 - val_loss: 1.2575
# Epoch 322/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9239 - val_loss: 1.2807
# Epoch 323/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8719 - val_loss: 1.3148
# Epoch 324/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9316 - val_loss: 1.2521
# Epoch 325/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9213 - val_loss: 1.2819
# Epoch 326/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8725 - val_loss: 1.3112
# Epoch 327/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9333 - val_loss: 1.2564
# Epoch 328/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9248 - val_loss: 1.2760
# Epoch 329/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.8728 - val_loss: 1.3075
# Epoch 330/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9331 - val_loss: 1.2561
# Epoch 331/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9237 - val_loss: 1.2785
# Epoch 332/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8724 - val_loss: 1.3128
# Epoch 333/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9314 - val_loss: 1.2518
# Epoch 334/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9207 - val_loss: 1.2829
# Epoch 335/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8727 - val_loss: 1.3100
# Epoch 336/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9339 - val_loss: 1.2584
# Epoch 337/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9246 - val_loss: 1.2778
# Epoch 338/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8722 - val_loss: 1.3138
# Epoch 339/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9307 - val_loss: 1.2504
# Epoch 340/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9209 - val_loss: 1.2806
# Epoch 341/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3104
# Epoch 342/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2552
# Epoch 343/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9237 - val_loss: 1.2781
# Epoch 344/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8724 - val_loss: 1.3111
# Epoch 345/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9310 - val_loss: 1.2518
# Epoch 346/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9204 - val_loss: 1.2838
# Epoch 347/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8724 - val_loss: 1.3119
# Epoch 348/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9329 - val_loss: 1.2564
# Epoch 349/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9251 - val_loss: 1.2748
# Epoch 350/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8726 - val_loss: 1.3054
# Epoch 351/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9326 - val_loss: 1.2558
# Epoch 352/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9233 - val_loss: 1.2794
# Epoch 353/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8720 - val_loss: 1.3149
# Epoch 354/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9312 - val_loss: 1.2519
# Epoch 355/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9206 - val_loss: 1.2825
# Epoch 356/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8724 - val_loss: 1.3097
# Epoch 357/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2561
# Epoch 358/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9243 - val_loss: 1.2757
# Epoch 359/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8724 - val_loss: 1.3075
# Epoch 360/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9317 - val_loss: 1.2533
# Epoch 361/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9209 - val_loss: 1.2821
# Epoch 362/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8726 - val_loss: 1.3078
# Epoch 363/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9341 - val_loss: 1.2595
# Epoch 364/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9270 - val_loss: 1.2693
# Epoch 365/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8730 - val_loss: 1.3016
# Epoch 366/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9324 - val_loss: 1.2550
# Epoch 367/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9215 - val_loss: 1.2813
# Epoch 368/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8729 - val_loss: 1.3091
# Epoch 369/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9330 - val_loss: 1.2562
# Epoch 370/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9241 - val_loss: 1.2747
# Epoch 371/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8724 - val_loss: 1.3062
# Epoch 372/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2538
# Epoch 373/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9212 - val_loss: 1.2808
# Epoch 374/500
# 3/3 [==============================] - 0s 20ms/step - loss: 0.8721 - val_loss: 1.3098
# Epoch 375/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9328 - val_loss: 1.2557
# Epoch 376/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9238 - val_loss: 1.2745
# Epoch 377/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8724 - val_loss: 1.3057
# Epoch 378/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2557
# Epoch 379/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9229 - val_loss: 1.2768
# Epoch 380/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8721 - val_loss: 1.3107
# Epoch 381/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9321 - val_loss: 1.2535
# Epoch 382/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9218 - val_loss: 1.2778
# Epoch 383/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8725 - val_loss: 1.3071
# Epoch 384/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9327 - val_loss: 1.2558
# Epoch 385/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9234 - val_loss: 1.2753
# Epoch 386/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8721 - val_loss: 1.3079
# Epoch 387/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9318 - val_loss: 1.2533
# Epoch 388/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9211 - val_loss: 1.2797
# Epoch 389/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8721 - val_loss: 1.3075
# Epoch 390/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9332 - val_loss: 1.2575
# Epoch 391/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9250 - val_loss: 1.2716
# Epoch 392/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8723 - val_loss: 1.3018
# Epoch 393/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2565
# Epoch 394/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9229 - val_loss: 1.2765
# Epoch 395/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8718 - val_loss: 1.3115
# Epoch 396/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9324 - val_loss: 1.2544
# Epoch 397/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9228 - val_loss: 1.2744
# Epoch 398/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8722 - val_loss: 1.3050
# Epoch 399/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9325 - val_loss: 1.2557
# Epoch 400/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9228 - val_loss: 1.2756
# Epoch 401/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8719 - val_loss: 1.3090
# Epoch 402/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9321 - val_loss: 1.2541
# Epoch 403/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9220 - val_loss: 1.2761
# Epoch 404/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8724 - val_loss: 1.3050
# Epoch 405/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9322 - val_loss: 1.2549
# Epoch 406/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9220 - val_loss: 1.2768
# Epoch 407/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8722 - val_loss: 1.3073
# Epoch 408/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9320 - val_loss: 1.2540
# Epoch 409/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9216 - val_loss: 1.2768
# Epoch 410/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8723 - val_loss: 1.3067
# Epoch 411/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9322 - val_loss: 1.2548
# Epoch 412/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9222 - val_loss: 1.2756
# Epoch 413/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8723 - val_loss: 1.3049
# Epoch 414/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9319 - val_loss: 1.2544
# Epoch 415/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9215 - val_loss: 1.2771
# Epoch 416/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8721 - val_loss: 1.3080
# Epoch 417/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9326 - val_loss: 1.2559
# Epoch 418/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9235 - val_loss: 1.2723
# Epoch 419/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.8721 - val_loss: 1.3028
# Epoch 420/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9320 - val_loss: 1.2547
# Epoch 421/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9213 - val_loss: 1.2773
# Epoch 422/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8724 - val_loss: 1.3053
# Epoch 423/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9327 - val_loss: 1.2564
# Epoch 424/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9234 - val_loss: 1.2723
# Epoch 425/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8719 - val_loss: 1.3037
# Epoch 426/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9315 - val_loss: 1.2533
# Epoch 427/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9219 - val_loss: 1.2739
# Epoch 428/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8724 - val_loss: 1.3005
# Epoch 429/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9332 - val_loss: 1.2583
# Epoch 430/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9243 - val_loss: 1.2711
# Epoch 431/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8718 - val_loss: 1.3033
# Epoch 432/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9313 - val_loss: 1.2528
# Epoch 433/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9213 - val_loss: 1.2746
# Epoch 434/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8724 - val_loss: 1.3017
# Epoch 435/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9327 - val_loss: 1.2569
# Epoch 436/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9232 - val_loss: 1.2725
# Epoch 437/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8717 - val_loss: 1.3051
# Epoch 438/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9324 - val_loss: 1.2556
# Epoch 439/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9226 - val_loss: 1.2727
# Epoch 440/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8722 - val_loss: 1.3008
# Epoch 441/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - val_loss: 1.2566
# Epoch 442/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9226 - val_loss: 1.2731
# Epoch 443/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8720 - val_loss: 1.3029
# Epoch 444/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9324 - val_loss: 1.2559
# Epoch 445/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9223 - val_loss: 1.2730
# Epoch 446/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8721 - val_loss: 1.3020
# Epoch 447/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9327 - val_loss: 1.2568
# Epoch 448/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9231 - val_loss: 1.2716
# Epoch 449/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8717 - val_loss: 1.3036
# Epoch 450/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9326 - val_loss: 1.2565
# Epoch 451/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9231 - val_loss: 1.2710
# Epoch 452/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8717 - val_loss: 1.3021
# Epoch 453/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9314 - val_loss: 1.2534
# Epoch 454/500
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9216 - val_loss: 1.2725
# Epoch 455/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8723 - val_loss: 1.2988
# Epoch 456/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9331 - val_loss: 1.2585
# Epoch 457/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9241 - val_loss: 1.2697
# Epoch 458/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8716 - val_loss: 1.3015
# Epoch 459/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9313 - val_loss: 1.2531
# Epoch 460/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9212 - val_loss: 1.2730
# Epoch 461/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8722 - val_loss: 1.2998
# Epoch 462/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9327 - val_loss: 1.2573
# Epoch 463/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9231 - val_loss: 1.2708
# Epoch 464/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8719 - val_loss: 1.2995
# Epoch 465/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9323 - val_loss: 1.2561
# Epoch 466/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9218 - val_loss: 1.2729
# Epoch 467/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8722 - val_loss: 1.2993
# Epoch 468/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9328 - val_loss: 1.2575
# Epoch 469/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9230 - val_loss: 1.2700
# Epoch 470/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8719 - val_loss: 1.2984
# Epoch 471/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9325 - val_loss: 1.2567
# Epoch 472/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9220 - val_loss: 1.2718
# Epoch 473/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8723 - val_loss: 1.2979
# Epoch 474/500
# 3/3 [==============================] - 0s 26ms/step - loss: 0.9338 - val_loss: 1.2600
# Epoch 475/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9250 - val_loss: 1.2654
# Epoch 476/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8720 - val_loss: 1.2987
# Epoch 477/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9316 - val_loss: 1.2537
# Epoch 478/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9211 - val_loss: 1.2718
# Epoch 479/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8725 - val_loss: 1.2952
# Epoch 480/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9341 - val_loss: 1.2617
# Epoch 481/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9263 - val_loss: 1.2637
# Epoch 482/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8720 - val_loss: 1.2969
# Epoch 483/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9312 - val_loss: 1.2532
# Epoch 484/500
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9204 - val_loss: 1.2738
# Epoch 485/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8723 - val_loss: 1.2990
# Epoch 486/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9328 - val_loss: 1.2581
# Epoch 487/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9237 - val_loss: 1.2682
# Epoch 488/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8714 - val_loss: 1.2991
# Epoch 489/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9314 - val_loss: 1.2542
# Epoch 490/500
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9210 - val_loss: 1.2724
# Epoch 491/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8722 - val_loss: 1.2970
# Epoch 492/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9332 - val_loss: 1.2594
# Epoch 493/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9244 - val_loss: 1.2664
# Epoch 494/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8715 - val_loss: 1.2968
# Epoch 495/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9319 - val_loss: 1.2555
# Epoch 496/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9216 - val_loss: 1.2704
# Epoch 497/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8722 - val_loss: 1.2946
# Epoch 498/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.9337 - val_loss: 1.2607
# Epoch 499/500
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9251 - val_loss: 1.2643
# Epoch 500/500
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8717 - val_loss: 1.2981

# %%
#training loss mae/validation loss - mae
history_lstm.history['loss'][-1], history_lstm.history['val_loss'][-1]
# Out:
# (0.8717350363731384, 1.29806649684906)

# %%
test_values = df_usa1_test.index.to_list()
future_month = []
for i in range(1, 13):
    test_values.append(df_usa1_test.index[-1] + relativedelta(months=i))
    
X_test = scaler.transform(pd.to_datetime(test_values).values.reshape(-1, 1))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
lstm_pred = model.predict(X_test)
lstm_predictions = pd.DataFrame({'datetime':pd.to_datetime(test_values), 'lstm_pred':lstm_pred.flatten()})
#flatten from 2s to 1 to array

# %%
#Visualise prediction
plt.figure(figsize=(15,5),facecolor='#ECECEC')
Time_series=sns.lineplot(x=df_usa1.index,y='value',data=df_usa1,color='#880808', linewidth=1.5,label='USA')
Time_series=sns.lineplot(x="datetime",y="lstm_pred",data=lstm_predictions,color='#50C878', linewidth=1.5, label='USA predicted')
Time_series.set_title('Sirloin steak prices in USA from 1997-2021',fontsize=20)
Time_series.set_ylabel('Price per Kg.',fontsize=20)
Time_series.set_xlabel('Year',fontsize=20)
plt.grid()
