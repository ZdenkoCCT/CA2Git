# %% [markdown]
# ## Data Cleaning

# %%
#import  os libraries. Also importing warnings to disbale Python warning messages
import os
import warnings
warnings.filterwarnings('ignore')
files_list =os.listdir('.')
files_list
# Out:
# ['.git',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  'Average price 1970 -2001.csv',
#  'Average price 2001-2011.csv',
#  'Average price 2011-2022.csv',
#  'beef export 1930 -2020.csv',
#  'BeefVeal_MonthlyFull us 2001-2022.xlsx',
#  'CA2.ipynb',
#  'Continues_Assignment_2_Zdenko_Zahorec_sbs22090_MSc in Data Analytics (SB+) - Feb 2022 - 2022 - YR1.docx',
#  'Download links.txt',
#  'export by month ctle irl 1970-2022.csv',
#  'tweets_organic_food ireland.csv',
#  'Unlimited tweets.ipynb',
#  'US Beef Price.xls',
#  'US Beef Price.xlsx',
#  '_Twitter API.ipynb']

# %%
#import pandas to load the data into the dataframe
import pandas as pd

# %%
df_irl1= pd.read_csv(r'Average price 1970 -2001.csv')
#seting columns dispay option to 'max'- to see all columns in dataset
pd.set_option('display.max.columns', None)
df_irl1.head()
# Out:
#   STATISTIC              Statistic2  TLIST(M1)    Month  C02438V02948  \
# 0     CPM08  National Average Price     199701  1997M01         10010
# 1     CPM08  National Average Price     199701  1997M01         10020
# 2     CPM08  National Average Price     199701  1997M01         10030
# 3     CPM08  National Average Price     199701  1997M01         10040
# 4     CPM08  National Average Price     199701  1997M01         10050
#
#                  Consumer Item UNIT  VALUE
# 0          Round steak per kg.  IEP  6.119
# 1        Sirloin steak per kg.  IEP  8.053
# 2            Rib steak per kg.  IEP  4.023
# 3  Leg beef (boneless) per kg.  IEP  4.269
# 4    Brisket pot roast per kg.  IEP  4.097

# %%
df_irl1 = df_irl1.pivot_table('VALUE', ['TLIST(M1)'], 'Consumer Item')
df_irl1= df_irl1.rename_axis(None,axis=1)
df_irl1= df_irl1.reset_index()

# %%
df_irl1=df_irl1.drop(df_irl1.iloc[:, 1:10], axis=1).drop(df_irl1.iloc[:, 11:39], axis=1).drop(df_irl1.iloc[:, 40:52], axis=1).drop(df_irl1.iloc[:, 54:56], axis=1).drop(df_irl1.iloc[:, 57:], axis=1)
df_irl1 = df_irl1.rename(columns={'TLIST(M1)': 'Date','Round steak per kg.':'Round Steak','Sirloin steak per kg.':'Stirloin Steak','Rib steak per kg.':'Ryb Steak','Leg beef (boneless) per kg.':'Beef Leg','Brisket pot roast per kg.':'Brisket'})
print(df_irl1.info())
df_irl1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            59 non-null     int64
#  1   Brisket         59 non-null     float64
#  2   Beef Leg        59 non-null     float64
#  3   Ryb Steak       59 non-null     float64
#  4   Round Steak     59 non-null     float64
#  5   Stirloin Steak  59 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 2.9 KB
# None
#      Date  Brisket  Beef Leg  Ryb Steak  Round Steak  Stirloin Steak
# 0  199701    4.097     4.269      4.023        6.119           8.053
# 1  199702    4.041     4.252      4.077        6.175           8.276
# 2  199703    4.067     4.219      4.092        6.059           8.124
# 3  199704    4.053     4.283      4.047        6.161           8.503
# 4  199705    4.055     4.268      3.946        6.138           8.397

# %%
df_irl2= pd.read_csv(r'Average price 2001-2011.csv')
#seting columns dispay option to 'max'- to see all columns in dataset
pd.set_option('display.max.columns', None)
#df_irl2

# %%
df_irl2 = df_irl2.pivot_table('VALUE', ['TLIST(M1)'], 'Consumer Item')
df_irl2= df_irl2.rename_axis(None,axis=1)
df_irl2= df_irl2.reset_index()
df_irl2.head()
# Out:
#    TLIST(M1)  1 litre full fat milk per ltr.  1 litre, low fat milk per ltr.  \
# 0     200112                           0.841                           0.846
# 1     200201                           0.842                           0.847
# 2     200202                           0.845                           0.850
# 3     200203                           0.844                           0.848
# 4     200204                           0.846                           0.850
#
#    2 litre full fat milk per 2 ltr.  Ale - draught bar (1 pint)  \
# 0                               NaN                       3.099
# 1                               NaN                       3.126
# 2                               NaN                       3.143
# 3                               NaN                       3.220
# 4                               NaN                       3.264
#
#    Bananas per kg.  Best back rashers per kg.  \
# 0            1.685                      9.916
# ...

# %%
df_irl2=df_irl2.drop(df_irl2.iloc[:, 1:63], axis=1).drop(df_irl2.iloc[:, 64:65], axis=1).drop(df_irl2.iloc[:, 66:68], axis=1).drop(df_irl2.iloc[:, 70:74], axis=1).drop(df_irl2.iloc[:, 75:], axis=1)
#df_irl2 = df_irl2.rename(columns={'TLIST(M1)': 'Date','Round steak per kg.':'Round Steak','Sirloin steak per kg.':'Stirloin Steak','Rib steak per kg.':'Ryb Steak','Leg beef (boneless) per kg.':'Beef Leg','Brisket pot roast per kg.':'Brisket'})
print(df_irl2.info())
df_irl2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   TLIST(M1)                         121 non-null    int64
#  1   Roast beef topside/rib per kg.    121 non-null    float64
#  2   Round steak per kg.               120 non-null    float64
#  3   Sirloin steak per kg.             121 non-null    float64
#  4   Sliced/diced beef pieces per kg.  121 non-null    float64
#  5   Striploin steak per kg.           121 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.8 KB
# None
#    TLIST(M1)  Roast beef topside/rib per kg.  Round steak per kg.  \
# 0     200112                           8.726                8.414
# 1     200201                           8.648                8.696
# 2     200202                           8.666                8.643
# ...

# %%
df_irl3= pd.read_csv(r'Average price 2011-2022.csv')
#seting columns dispay option to 'max'- to see all columns in dataset
pd.set_option('display.max.columns', None)
#df_irl3.head(50)

# %%
df_irl3 = df_irl3.pivot_table('VALUE', ['TLIST(M1)'], 'Consumer Item')
df_irl3= df_irl3.rename_axis(None,axis=1)
df_irl3= df_irl3.reset_index()
df_irl3.head()
# Out:
#    TLIST(M1)  Ale - draught bar (1 pint)  Bananas per kg  \
# 0     201201                       4.005           1.330
# 1     201202                       4.035           1.359
# 2     201203                       4.028           1.371
# 3     201204                       4.026           1.362
# 4     201205                       4.028           1.375
#
#    Best back rashers per kg  Brandy - bar (single) per ½  glass  \
# 0                    10.349                               4.271
# 1                    10.775                               4.298
# 2                    10.613                               4.302
# 3                    10.968                               4.300
# 4                    10.772                               4.308
#
#    Brandy - take home (70cl  bottle)  Bread, brown sliced pan, large (800g)  \
# 0                             25.681                                  1.539
# 1                             25.539                                  1.541
# ...

# %%
df_irl3=df_irl3.drop(df_irl3.iloc[:, 1:63], axis=1).drop(df_irl3.iloc[:, 64:65], axis=1).drop(df_irl3.iloc[:, 66:68], axis=1).drop(df_irl3.iloc[:, 70:74], axis=1).drop(df_irl3.iloc[:, 75:], axis=1)
#df_irl2 = df_irl2.rename(columns={'TLIST(M1)': 'Date','Round steak per kg.':'Round Steak','Sirloin steak per kg.':'Stirloin Steak','Rib steak per kg.':'Ryb Steak','Leg beef (boneless) per kg.':'Beef Leg','Brisket pot roast per kg.':'Brisket'})
print(df_irl3.info())
df_irl3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   TLIST(M1)                           122 non-null    int64
#  1   Stout - take home (50cl can)        122 non-null    float64
#  2   Tea bags per 80                     122 non-null    float64
#  3   Uncooked chicken medium size 1.6kg  122 non-null    float64
#  4   Vodka - bar (single) per ½  glass   113 non-null    float64
#  5   White, self raising flour per 2 kg  122 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.8 KB
# None
#    TLIST(M1)  Stout - take home (50cl can)  Tea bags per 80  \
# 0     201201                         2.036            2.788
# 1     201202                         2.061            2.854
# 2     201203                         2.065            2.949
# ...
